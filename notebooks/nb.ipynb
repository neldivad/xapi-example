# %% [markdown]
# # Twitter Followings Example
#
# This notebook loads cached followings (JSON/CSV) if present, or queries the API and displays a DataFrame.

# %%
import os
import requests
from dotenv import load_dotenv, find_dotenv
import pandas as pd

pd.set_option('display.max_columns', None)

# Local module
from pathlib import Path
import sys
project_root = Path.cwd().parent  # assumes notebook is in xapi-ex1/notebooks
sys.path.append(str(project_root / 'src'))

# %%
from users import (
    get_recent_followings, 
    get_recent_followers,
    get_recent_followings_cached,
    get_recent_followers_cached,
    search_tweets_advanced,
    get_user_tweets, 
    get_user_tweets_cached,
    save_tweet_cache,
    load_tweet_cache,
)
from schema.tweets import (
    collapse_dicts, 
    collapse_dataframe, 
    TRUNCATED_TWEET_FIELDS
)


# Load env
load_dotenv(find_dotenv())
API_KEY = os.getenv('twitter_apiio_key')
if not API_KEY:
    raise RuntimeError('twitter_apiio_key not set in environment')

# %%
print(API_KEY)
# Out:
# new1_08ebc749d35b44c198d19b1b022a269e

# %% [markdown]
# ## Followings

# %%
# Params
USERNAME = 'ern1337'  # change as needed
LIMIT = 20  # multiples of 20-200 recommended
USE_CACHE_FIRST = True

# %%
# Try cache else fetch - now using the new cached function

if USE_CACHE_FIRST:
    data = get_recent_followings_cached(USERNAME, limit=LIMIT, api_key=API_KEY)
else:
    data = get_recent_followings(USERNAME, limit=LIMIT, api_key=API_KEY)
# Out:
# 🔄 Cache miss: fetching followings from API...
# 💾 Cached 20 followings

# %%
# Normalize to DataFrame
df_followings = pd.json_normalize(data.get('followings', []))
print(f"Rows: {len(df_followings)}")

df_followings.head(2)
# Out:
# Rows: 20
#                     id         name screen_name    userName  \
# 0  1695126229446479872       Zephyr   zephyr_z9   zephyr_z9
# 1             17838032  Jason Cohen  asmartbear  asmartbear
#
#                     location                      url  \
# 0                             https://t.co/Lyb7ipudz2
# 1  Join 65,000 subscribers →  https://t.co/xPvZmRxbhW
#
#                                          description email  protected  \
# 0                                       DMs are open  None      False
# 1  Keyword, buzzword, half-truth, adjective, hey ...  None      False
#
#    verified  followers_count  following_count  friends_count  \
# 0     False             8960              443            443
# 1     False            44569              707            707
#
#    favourites_count  statuses_count  media_tweets_count  \
# 0             58128           19556                1591
# 1             49367           54117                 305
#
#                        created_at  \
# 0  Fri Aug 25 17:30:19 +0000 2023
# 1  Wed Dec 03 15:00:16 +0000 2008
#
#                                   profile_banner_url  \
# 0                                               None
# 1  https://pbs.twimg.com/profile_banners/17838032...
#
#                              profile_image_url_https  can_dm
# 0  https://pbs.twimg.com/profile_images/183780299...   False
# 1  https://pbs.twimg.com/profile_images/378800000...   False

# %% [markdown]
# ## Followers

# %%
# Try cache else fetch - now using the new cached function

if USE_CACHE_FIRST:
    data = get_recent_followers_cached(USERNAME, limit=LIMIT, api_key=API_KEY)
else:
    data = get_recent_followers(USERNAME, limit=LIMIT, api_key=API_KEY)
# Out:
# 🔄 Cache miss: fetching followers from API...
# 💾 Cached 20 followers

# %%
# Normalize to DataFrame
df_followers = pd.json_normalize(data.get('followers', []))
print(f"Rows: {len(df_followers)}")

df_followers.head(2)
# Out:
# Rows: 20
#                     id          name      screen_name         userName  \
# 0  1944410785913917440    Schneemaus  92KXwDZ4ymJ2R8F  92KXwDZ4ymJ2R8F
# 1  1948734096261480453  MichelleIII.    1ltxDE35NSiy9    1ltxDE35NSiy9
#
#   location   url description email  protected  verified  followers_count  \
# 0           None              None      False     False                3
# 1           None              None      False     False                4
#
#    following_count  friends_count  favourites_count  statuses_count  \
# 0              399            399                 0               0
# 1              174            174                 0               0
#
#    media_tweets_count                      created_at profile_banner_url  \
# 0                   0  Sun Jul 13 14:57:22 +0000 2025               None
# 1                   0  Fri Jul 25 13:16:40 +0000 2025               None
#
#                              profile_image_url_https  can_dm
# 0  https://pbs.twimg.com/profile_images/196531039...   False
# 1  https://pbs.twimg.com/profile_images/194873419...   False

# %% [markdown]
# ## tweets

# %%
# search_tweets_advanced(
#     api_key=API_KEY,
#     query="from:nelvOfficial min_faves:30"
# )

# %%
# Params
USER_NAME = "nelvOfficial"   # or set USER_ID = "44196397"
USER_ID = 44196397
INCLUDE_REPLIES = True
LIMIT = 40                  # total tweets desired
start_date = "2025-01-01"
end_date = "2025-09-09"
min_faves = 10

# %%
# resp = get_user_tweets(
#     api_key=API_KEY,
#     username=USER_NAME,
#     limit=LIMIT,
#     start_date=start_date,
#     end_date=end_date,
#     min_faves=min_faves,
#     include_replies=INCLUDE_REPLIES,
# )
# tweets = resp["tweets"]

# %%
resp = get_user_tweets_cached(
    api_key=API_KEY,
    username=USER_NAME,
    limit=LIMIT,
    start_date=start_date,
    end_date=end_date,
    min_faves=min_faves,
    include_replies=INCLUDE_REPLIES,
)
tweets = resp["tweets"]
# Out:
# 🔄 C-Miss: Fetching with Q: `from:nelvOfficial since:2025-01-01 until:2025-09-09 min_faves:10`
# 💾 Cached 40 tweets

# %%
resp
# Out:
# {'tweets': [{'type': 'tweet',
#    'id': '1965155350392570283',
#    'url': 'https://x.com/nelvOfficial/status/1965155350392570283',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1965155350392570283',
#    'text': '@martianwyrdlord Every man learns this by 25 - 35. \n\nInsane how much damage the federal reserve system can cause to the global civilization',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 0,
#    'likeCount': 25,
#    'quoteCount': 0,
#    'viewCount': 488,
#    'createdAt': 'Mon Sep 08 20:48:41 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 1,
#    'isReply': True,
#    'inReplyToId': '1965123155116380494',
#    'conversationId': '1965123155116380494',
#    'displayTextRange': [17, 139],
#    'inReplyToUserId': '1609651923363168258',
#    'inReplyToUsername': 'martianwyrdlord',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1609651923363168258',
#       'indices': [0, 16],
#       'name': 'John Carter',
#       'screen_name': 'martianwyrdlord'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1964882628810834046',
#    'url': 'https://x.com/nelvOfficial/status/1964882628810834046',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1964882628810834046',
#    'text': '@ElizabethHolmes Do you want to pivot your career to stand-up comedy? You are natural at this',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 2,
#    'replyCount': 0,
#    'likeCount': 85,
#    'quoteCount': 0,
#    'viewCount': 4680,
#    'createdAt': 'Mon Sep 08 02:44:59 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 0,
#    'isReply': True,
#    'inReplyToId': '1964838363845845133',
#    'conversationId': '1964838363845845133',
#    'displayTextRange': [17, 93],
#    'inReplyToUserId': None,
#    'inReplyToUsername': None,
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1629336979',
#       'indices': [0, 16],
#       'name': 'Elizabeth Holmes',
#       'screen_name': 'ElizabethHolmes'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': True,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1964841696967213403',
#    'url': 'https://x.com/nelvOfficial/status/1964841696967213403',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1964841696967213403',
#    'text': "@redaction Public-employee salary to private-employee salary ratio is predictive of the negative quality of policies. \n\nArgentina has the highest Public/Private salary in the whole LatAm. \n\nIf you use the same logic and try to guess on EU, you'll probably find the same thing.",
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 0,
#    'likeCount': 38,
#    'quoteCount': 0,
#    'viewCount': 3842,
#    'createdAt': 'Mon Sep 08 00:02:20 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 4,
#    'isReply': True,
#    'inReplyToId': '1964840284392657159',
#    'conversationId': '1964840284392657159',
#    'displayTextRange': [11, 276],
#    'inReplyToUserId': '259897904',
#    'inReplyToUsername': 'redaction',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '259897904',
#       'indices': [0, 10],
#       'name': '@redaction',
#       'screen_name': 'redaction'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1964695638169547042',
#    'url': 'https://x.com/nelvOfficial/status/1964695638169547042',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1964695638169547042',
#    'text': "@boneGPT Im more surprised by how could someone manage to convince the PM of one of the most nationalistic and xenophobic country to think such a policy proposal would be good for their career. \n\nThere's a lot of juice in this whole thing.",
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 2,
#    'likeCount': 118,
#    'quoteCount': 0,
#    'viewCount': 5005,
#    'createdAt': 'Sun Sep 07 14:21:57 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 1,
#    'isReply': True,
#    'inReplyToId': '1964583026207433024',
#    'conversationId': '1964583026207433024',
#    'displayTextRange': [9, 239],
#    'inReplyToUserId': '1644739974028316672',
#    'inReplyToUsername': 'boneGPT',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1644739974028316672',
#       'indices': [0, 8],
#       'name': 'bone',
#       'screen_name': 'boneGPT'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1964432060623573229',
#    'url': 'https://x.com/nelvOfficial/status/1964432060623573229',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1964432060623573229',
#    'text': '@apralky Predicting trends requires understanding Lindy',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 1,
#    'replyCount': 0,
#    'likeCount': 15,
#    'quoteCount': 0,
#    'viewCount': 1387,
#    'createdAt': 'Sat Sep 06 20:54:35 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 1,
#    'isReply': True,
#    'inReplyToId': '1964427734765260863',
#    'conversationId': '1964427734765260863',
#    'displayTextRange': [9, 55],
#    'inReplyToUserId': '1700977169177206784',
#    'inReplyToUsername': 'apralky',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1700977169177206784',
#       'indices': [0, 8],
#       'name': 'yung macro 宏观年少传奇',
#       'screen_name': 'apralky'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1963855148859498682',
#    'url': 'https://x.com/nelvOfficial/status/1963855148859498682',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1963855148859498682',
#    'text': '@nearcyan Grifting has no peak. \n\nBtw, the broccoli haircut grifter signal still continues to work',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 3,
#    'replyCount': 0,
#    'likeCount': 48,
#    'quoteCount': 0,
#    'viewCount': 5434,
#    'createdAt': 'Fri Sep 05 06:42:08 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 6,
#    'isReply': True,
#    'inReplyToId': '1963845078964715751',
#    'conversationId': '1963845078964715751',
#    'displayTextRange': [10, 98],
#    'inReplyToUserId': '1128159740599656448',
#    'inReplyToUsername': 'nearcyan',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1128159740599656448',
#       'indices': [0, 9],
#       'name': 'near',
#       'screen_name': 'nearcyan'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1963803997023957023',
#    'url': 'https://x.com/nelvOfficial/status/1963803997023957023',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1963803997023957023',
#    'text': '@signulll chatgpt inherited its sycophancy from his ceo.',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 1,
#    'likeCount': 37,
#    'quoteCount': 0,
#    'viewCount': 1474,
#    'createdAt': 'Fri Sep 05 03:18:53 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 0,
#    'isReply': True,
#    'inReplyToId': '1963802818118033552',
#    'conversationId': '1963802818118033552',
#    'displayTextRange': [10, 56],
#    'inReplyToUserId': '1717671858521194496',
#    'inReplyToUsername': 'signulll',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1717671858521194496',
#       'indices': [0, 9],
#       'name': 'signüll',
#       'screen_name': 'signulll'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1963440133166043580',
#    'url': 'https://x.com/nelvOfficial/status/1963440133166043580',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1963440133166043580',
#    'text': '@julianweisser He is the same guy who wants 70% for having the idea and 30% for you who builds it',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 0,
#    'likeCount': 31,
#    'quoteCount': 0,
#    'viewCount': 2072,
#    'createdAt': 'Thu Sep 04 03:13:01 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 0,
#    'isReply': True,
#    'inReplyToId': '1963430112931545253',
#    'conversationId': '1963430112931545253',
#    'displayTextRange': [15, 97],
#    'inReplyToUserId': '11704332',
#    'inReplyToUsername': 'julianweisser',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '11704332',
#       'indices': [0, 14],
#       'name': 'weisser',
#       'screen_name': 'julianweisser'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1963358604377141634',
#    'url': 'https://x.com/nelvOfficial/status/1963358604377141634',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1963358604377141634',
#    'text': '@jxmnop databricks is worth $100B in series K. If MosaicAI is worth 100x 2023 prices, that would imply databricks has negative EV',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 2,
#    'likeCount': 20,
#    'quoteCount': 0,
#    'viewCount': 1416,
#    'createdAt': 'Wed Sep 03 21:49:03 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 2,
#    'isReply': True,
#    'inReplyToId': '1963352226396885193',
#    'conversationId': '1963352226396885193',
#    'displayTextRange': [8, 129],
#    'inReplyToUserId': '783098774130401280',
#    'inReplyToUsername': 'jxmnop',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '783098774130401280',
#       'indices': [0, 7],
#       'name': 'Jack Morris',
#       'screen_name': 'jxmnop'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1962032794575794306',
#    'url': 'https://x.com/nelvOfficial/status/1962032794575794306',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1962032794575794306',
#    'text': '@airkatakana its almost as if devaluing money and pushing all the debts to younger generation results in people having less sex',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 0,
#    'likeCount': 12,
#    'quoteCount': 0,
#    'viewCount': 701,
#    'createdAt': 'Sun Aug 31 06:00:45 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 1,
#    'isReply': True,
#    'inReplyToId': '1962021846905507981',
#    'conversationId': '1962021846905507981',
#    'displayTextRange': [13, 127],
#    'inReplyToUserId': '3116760553',
#    'inReplyToUsername': 'airkatakana',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '3116760553',
#       'indices': [0, 12],
#       'name': 'Air Katakana',
#       'screen_name': 'airkatakana'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1962026011614392830',
#    'url': 'https://x.com/nelvOfficial/status/1962026011614392830',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1962026011614392830',
#    'text': '@stevehou0 Broccoli haircut grifter signal never fails',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 0,
#    'likeCount': 30,
#    'quoteCount': 0,
#    'viewCount': 2610,
#    'createdAt': 'Sun Aug 31 05:33:48 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 1,
#    'isReply': True,
#    'inReplyToId': '1961815739058315449',
#    'conversationId': '1961815739058315449',
#    'displayTextRange': [11, 54],
#    'inReplyToUserId': '803639496386355200',
#    'inReplyToUsername': 'stevehou0',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '803639496386355200',
#       'indices': [0, 10],
#       'name': 'Steve Hou',
#       'screen_name': 'stevehou0'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1957650072407273520',
#    'url': 'https://x.com/nelvOfficial/status/1957650072407273520',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1957650072407273520',
#    'text': '@airkatakana see, this is how your bloodline got shamed all the way to wikipedia and LLM weights for centuries to come',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 1,
#    'replyCount': 0,
#    'likeCount': 20,
#    'quoteCount': 0,
#    'viewCount': 1009,
#    'createdAt': 'Tue Aug 19 03:45:23 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 0,
#    'isReply': True,
#    'inReplyToId': '1957649690113241443',
#    'conversationId': '1957641953853731185',
#    'displayTextRange': [13, 118],
#    'inReplyToUserId': '3116760553',
#    'inReplyToUsername': 'airkatakana',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '3116760553',
#       'indices': [0, 12],
#       'name': 'Air Katakana',
#       'screen_name': 'airkatakana'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1957648896462844044',
#    'url': 'https://x.com/nelvOfficial/status/1957648896462844044',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1957648896462844044',
#    'text': "@airkatakana I would bait my enemy into buying it, praise him publicly for doing it, and make fun of him for the rest of his household's history.",
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 1,
#    'likeCount': 39,
#    'quoteCount': 0,
#    'viewCount': 9150,
#    'createdAt': 'Tue Aug 19 03:40:42 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 0,
#    'isReply': True,
#    'inReplyToId': '1957641953853731185',
#    'conversationId': '1957641953853731185',
#    'displayTextRange': [13, 145],
#    'inReplyToUserId': '3116760553',
#    'inReplyToUsername': 'airkatakana',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '3116760553',
#       'indices': [0, 12],
#       'name': 'Air Katakana',
#       'screen_name': 'airkatakana'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1954093265554145481',
#    'url': 'https://x.com/nelvOfficial/status/1954093265554145481',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1954093265554145481',
#    'text': "@willdepue Gpt5 was a let down. \n\nBut the progress in just the last 2 years have been astronomical. \n\nNvidia's new generation chips are not even yet available for mainstream data centers, and they supposedly carry 100x more compute!",
#    'source': 'Twitter for iPhone',
#    'retweetCount': 2,
#    'replyCount': 2,
#    'likeCount': 118,
#    'quoteCount': 0,
#    'viewCount': 14393,
#    'createdAt': 'Sat Aug 09 08:11:54 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 11,
#    'isReply': True,
#    'inReplyToId': '1954091583306977641',
#    'conversationId': '1954091583306977641',
#    'displayTextRange': [11, 232],
#    'inReplyToUserId': '998575387067142144',
#    'inReplyToUsername': 'willdepue',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '998575387067142144',
#       'indices': [0, 10],
#       'name': 'will depue',
#       'screen_name': 'willdepue'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1950260053271073132',
#    'url': 'https://x.com/nelvOfficial/status/1950260053271073132',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1950260053271073132',
#    'text': "@atelicinvest &gt; Tried short selling a fraud. \n&gt; Doubles in price\n&gt; Close positions at loss\n&gt; Company is exposed as fraud 6 months later\n&gt; TFW I'll never do shorts DD nor trade on it ever again",
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 2,
#    'likeCount': 36,
#    'quoteCount': 0,
#    'viewCount': 3817,
#    'createdAt': 'Tue Jul 29 18:20:05 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 3,
#    'isReply': True,
#    'inReplyToId': '1950204645390922133',
#    'conversationId': '1950204645390922133',
#    'displayTextRange': [14, 207],
#    'inReplyToUserId': '2244127460',
#    'inReplyToUsername': 'atelicinvest',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '2244127460',
#       'indices': [0, 13],
#       'name': 'Unemployed Capital Allocator',
#       'screen_name': 'atelicinvest'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1950128903860691121',
#    'url': 'https://x.com/nelvOfficial/status/1950128903860691121',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1950128903860691121',
#    'text': '@IterIntellectus The comment sections are all egirls. Real life is a comedy',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 0,
#    'likeCount': 204,
#    'quoteCount': 0,
#    'viewCount': 5981,
#    'createdAt': 'Tue Jul 29 09:38:56 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 0,
#    'isReply': True,
#    'inReplyToId': '1950116418554327385',
#    'conversationId': '1950116418554327385',
#    'displayTextRange': [17, 75],
#    'inReplyToUserId': '1655936149733654530',
#    'inReplyToUsername': 'IterIntellectus',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1655936149733654530',
#       'indices': [0, 16],
#       'name': 'vittorio',
#       'screen_name': 'IterIntellectus'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1949542631580782783',
#    'url': 'https://x.com/nelvOfficial/status/1949542631580782783',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1949542631580782783',
#    'text': '@demiurgently But they will happily brag to you about their portfolio. \n\nMF, someone is slaving away to generate shareholder returns for your stock holdings',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 5,
#    'likeCount': 24,
#    'quoteCount': 2,
#    'viewCount': 13288,
#    'createdAt': 'Sun Jul 27 18:49:18 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 0,
#    'isReply': True,
#    'inReplyToId': '1949448656647802987',
#    'conversationId': '1949448656647802987',
#    'displayTextRange': [14, 156],
#    'inReplyToUserId': '1192327263527698433',
#    'inReplyToUsername': 'demiurgently',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1192327263527698433',
#       'indices': [0, 13],
#       'name': 'sydney',
#       'screen_name': 'demiurgently'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1949527992700694889',
#    'url': 'https://x.com/nelvOfficial/status/1949527992700694889',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1949527992700694889',
#    'text': '@BoringBiz_ Dumbass finance bro never learned the age old wisdom: \n\n"Never buy the 3 Fs" \n\nWhat you fly. \nWhat you float. \nWhat you (you know the one)',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 1,
#    'replyCount': 3,
#    'likeCount': 175,
#    'quoteCount': 1,
#    'viewCount': 8462,
#    'createdAt': 'Sun Jul 27 17:51:08 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 40,
#    'isReply': True,
#    'inReplyToId': '1949466295981801686',
#    'conversationId': '1949466295981801686',
#    'displayTextRange': [12, 150],
#    'inReplyToUserId': '1652717271469506565',
#    'inReplyToUsername': 'BoringBiz_',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1652717271469506565',
#       'indices': [0, 11],
#       'name': 'Boring_Business',
#       'screen_name': 'BoringBiz_'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1949481325624488060',
#    'url': 'https://x.com/nelvOfficial/status/1949481325624488060',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1949481325624488060',
#    'text': "@s8mb Same energy as Steam asking for your age when buying a 18+ game for an account that's 18+ yo",
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 1,
#    'likeCount': 362,
#    'quoteCount': 0,
#    'viewCount': 4211,
#    'createdAt': 'Sun Jul 27 14:45:42 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 1,
#    'isReply': True,
#    'inReplyToId': '1949380565234319796',
#    'conversationId': '1949380565234319796',
#    'displayTextRange': [6, 98],
#    'inReplyToUserId': '645503',
#    'inReplyToUsername': 's8mb',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
# ...
#    'conversationId': '1944734227892777295',
#    'displayTextRange': [16, 55],
#    'inReplyToUserId': '1793654453049937920',
#    'inReplyToUsername': 'chasedownleads',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1793654453049937920',
#       'indices': [0, 15],
#       'name': 'Chase Passive Income',
#       'screen_name': 'chasedownleads'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1944718383943225740',
#    'url': 'https://x.com/nelvOfficial/status/1944718383943225740',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1944718383943225740',
#    'text': '@Sloppy_McNuts When you start programming, your confidence changes',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 35,
#    'replyCount': 9,
#    'likeCount': 1592,
#    'quoteCount': 1,
#    'viewCount': 85331,
#    'createdAt': 'Mon Jul 14 11:19:28 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 20,
#    'isReply': True,
#    'inReplyToId': '1944670099832455655',
#    'conversationId': '1944670099832455655',
#    'displayTextRange': [15, 66],
#    'inReplyToUserId': '1513961428465725449',
#    'inReplyToUsername': 'Sloppy_McNuts',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1513961428465725449',
#       'indices': [0, 14],
#       'name': 'Arosam!',
#       'screen_name': 'Sloppy_McNuts'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1944714983881027654',
#    'url': 'https://x.com/nelvOfficial/status/1944714983881027654',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1944714983881027654',
#    'text': '@Cobratate Boy subscribing to Andrew Tate for alpha advice and masculinity*\n\nAndrew Tate:\n"Best I can do is shit posting and comedy"',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 1,
#    'replyCount': 0,
#    'likeCount': 44,
#    'quoteCount': 0,
#    'viewCount': 4975,
#    'createdAt': 'Mon Jul 14 11:05:57 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 1,
#    'isReply': True,
#    'inReplyToId': '1944713034699538742',
#    'conversationId': '1944713034699538742',
#    'displayTextRange': [11, 132],
#    'inReplyToUserId': '333357345',
#    'inReplyToUsername': 'Cobratate',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '333357345',
#       'indices': [0, 10],
#       'name': 'Andrew Tate',
#       'screen_name': 'Cobratate'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1944660490686447660',
#    'url': 'https://x.com/nelvOfficial/status/1944660490686447660',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1944660490686447660',
#    'text': "@Cobratate Andrew became a shitposter after jail. \n\n&gt; I don't have an opinion. I have 47 criminal charges against me!",
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 0,
#    'likeCount': 67,
#    'quoteCount': 0,
#    'viewCount': 2279,
#    'createdAt': 'Mon Jul 14 07:29:25 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 0,
#    'isReply': True,
#    'inReplyToId': '1944646780475576533',
#    'conversationId': '1944646780475576533',
#    'displayTextRange': [11, 120],
#    'inReplyToUserId': '333357345',
#    'inReplyToUsername': 'Cobratate',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '333357345',
#       'indices': [0, 10],
#       'name': 'Andrew Tate',
#       'screen_name': 'Cobratate'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1943583500579361239',
#    'url': 'https://x.com/nelvOfficial/status/1943583500579361239',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1943583500579361239',
#    'text': '@hunterhurleywx @WhiteHouse https://t.co/uhh9aZIM3C',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 0,
#    'likeCount': 27,
#    'quoteCount': 0,
#    'viewCount': 6864,
#    'createdAt': 'Fri Jul 11 08:09:51 +0000 2025',
#    'lang': 'qme',
#    'bookmarkCount': 0,
#    'isReply': True,
#    'inReplyToId': '1943510758416929104',
#    'conversationId': '1943493150644777199',
#    'displayTextRange': [27, 27],
#    'inReplyToUserId': '1520133961472786432',
#    'inReplyToUsername': 'hunterhurleywx',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {'media': [{'display_url': 'pic.twitter.com/uhh9aZIM3C',
#       'expanded_url': 'https://twitter.com/nelvOfficial/status/1943583500579361239/photo/1',
#       'ext_media_availability': {'status': 'Available'},
#       'id_str': '1943583487988240384',
#       'indices': [28, 51],
#       'media_key': '16_1943583487988240384',
#       'media_results': {'id': 'QXBpTWVkaWFSZXN1bHRzOgwAAgoAARr4/uKA2pAACgACGvj+5W9X0dcAAA==',
#        'result': {'__typename': 'ApiMedia',
#         'id': 'QXBpTWVkaWE6DAACCgABGvj+4oDakAAKAAIa+P7lb1fR1wAA',
#         'media_key': '16_1943583487988240384'}},
#       'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/Gvj-4oDakAAgZq-.jpg',
#       'original_info': {'focus_rects': [], 'height': 130, 'width': 220},
#       'sizes': {'large': {'h': 130, 'w': 220}},
#       'type': 'animated_gif',
#       'url': 'https://t.co/uhh9aZIM3C',
#       'video_info': {'aspect_ratio': [22, 13],
#        'variants': [{'bitrate': 0,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/tweet_video/Gvj-4oDakAAgZq-.mp4'}]}}]},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1520133961472786432',
#       'indices': [0, 15],
#       'name': 'Hunter Hurley',
#       'screen_name': 'hunterhurleywx'},
#      {'id_str': '1879644163769335808',
#       'indices': [16, 27],
#       'name': 'The White House',
#       'screen_name': 'WhiteHouse'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1943581508276531616',
#    'url': 'https://x.com/nelvOfficial/status/1943581508276531616',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1943581508276531616',
#    'text': '@ali_debow The real business model of college',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 1,
#    'likeCount': 36,
#    'quoteCount': 0,
#    'viewCount': 2902,
#    'createdAt': 'Fri Jul 11 08:01:56 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 0,
#    'isReply': True,
#    'inReplyToId': '1943507716787339583',
#    'conversationId': '1943507716787339583',
#    'displayTextRange': [11, 45],
#    'inReplyToUserId': '1443087609761124355',
#    'inReplyToUsername': 'ali_debow',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 308,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8813,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1806,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1443087609761124355',
#       'indices': [0, 10],
#       'name': 'Ali Debow',
#       'screen_name': 'ali_debow'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None}],
#  'has_next_page': True,
#  'next_cursor': 'DAADDAABCgABG0WiYRybgasKAAIa-P0VkNcxoAAIAAIAAAACCAADAAAAAAgABAAAAAEKAAUbRiFwdgAnEAoABhtGIXB1_7HgAAA',
#  'status': 'success',
#  'message': 'Fetched 40 tweets for query: `from:nelvOfficial since:2025-01-01 until:2025-09-09 min_faves:10`'}

# %%
for tweet in tweets:
    print(tweet['text'])
# Out:
# @martianwyrdlord Every man learns this by 25 - 35.
#
# Insane how much damage the federal reserve system can cause to the global civilization
# @ElizabethHolmes Do you want to pivot your career to stand-up comedy? You are natural at this
# @redaction Public-employee salary to private-employee salary ratio is predictive of the negative quality of policies.
#
# Argentina has the highest Public/Private salary in the whole LatAm.
#
# If you use the same logic and try to guess on EU, you'll probably find the same thing.
# @boneGPT Im more surprised by how could someone manage to convince the PM of one of the most nationalistic and xenophobic country to think such a policy proposal would be good for their career.
#
# There's a lot of juice in this whole thing.
# @apralky Predicting trends requires understanding Lindy
# @nearcyan Grifting has no peak.
#
# Btw, the broccoli haircut grifter signal still continues to work
# @signulll chatgpt inherited its sycophancy from his ceo.
# @julianweisser He is the same guy who wants 70% for having the idea and 30% for you who builds it
# @jxmnop databricks is worth $100B in series K. If MosaicAI is worth 100x 2023 prices, that would imply databricks has negative EV
# @airkatakana its almost as if devaluing money and pushing all the debts to younger generation results in people having less sex
# @stevehou0 Broccoli haircut grifter signal never fails
# @airkatakana see, this is how your bloodline got shamed all the way to wikipedia and LLM weights for centuries to come
# @airkatakana I would bait my enemy into buying it, praise him publicly for doing it, and make fun of him for the rest of his household's history.
# @willdepue Gpt5 was a let down.
#
# But the progress in just the last 2 years have been astronomical.
#
# Nvidia's new generation chips are not even yet available for mainstream data centers, and they supposedly carry 100x more compute!
# @atelicinvest &gt; Tried short selling a fraud.
# &gt; Doubles in price
# &gt; Close positions at loss
# &gt; Company is exposed as fraud 6 months later
# &gt; TFW I'll never do shorts DD nor trade on it ever again
# @IterIntellectus The comment sections are all egirls. Real life is a comedy
# @demiurgently But they will happily brag to you about their portfolio.
#
# MF, someone is slaving away to generate shareholder returns for your stock holdings
# @BoringBiz_ Dumbass finance bro never learned the age old wisdom:
#
# "Never buy the 3 Fs"
#
# What you fly.
# What you float.
# What you (you know the one)
# @s8mb Same energy as Steam asking for your age when buying a 18+ game for an account that's 18+ yo
# I build an AI >> human-sounding text generator.
#
# Mainly just for myself to use it bc im sick of all the special characters and emdash that comes from AI.
#
# I spend most of 90% of my time writing original stuff, then let AI cleanup and format, but the generated tokens mean I need to do a 2nd round of cleaning which is annoying.
#
# Currently not opened for public usage bc its so annoying to deal with auth, token management, key management.
#
# I just let anyone I personally know use my SK, from the Superuser key parameter.
#
# Its just a shitty GPT wrapper that you can easily add a custom prompt on your original text layer anyway.
#
# However, if at least 10 people want this thing, I could be bothered to buy a custom domain + setup all the stripe and stuff.
# @chasedownleads https://t.co/U3EkoyAPXK
# @apralky His best lectures happened before 2008.
#
# Predicted the tech outperformance, predicted biotech underperformance, predicted woke politics, predicted the racket of universities.
# @paulg EU:
# "You can just say things!"
#
# Also EU:
# "N-n-no no not that one!"
# @apralky https://t.co/30h2lUKJXd
# @chasedownleads Brilliant move. You promoted your employees into customers!!
# @chasedownleads Guess who hired the woman into the company and promote her to Chief HR Officer?
# @JackieD53172077 @SCHIZO_FREQ What kind of guys are you people dating with.....???
# @SCHIZO_FREQ Delete this. If the incels could read they would be very disappointed
# @SCHIZO_FREQ AI bf doesn't pay rents, doesn't fix pipes, doesn't take out the trash, doesn't get rid of the pests
# @nickfloats boomer maybe https://t.co/yD5vK2IKr8
# @MLSophist Twitter is for founder mindsets.
#
# LinkedIn is for employee mindsets.
# @chasedownleads Guess who owns the video editing studio contracted by DC
# @Suhail On my founder journey. Wished I read this earlier.
#
# TLDR: don't build. Don't get attached to your ideas. Make hypothesis and ask more questions.
#
# Progress is not made from doing. More progress is made after doing something you understand.
#
# https://t.co/iQ69vF7HE0
# @nhentaiOfficial Now I see why OnlyFans have more revenue than OpenAI
# @chasedownleads Guess who is ordering all the takeouts?
# @Sloppy_McNuts When you start programming, your confidence changes
# @Cobratate Boy subscribing to Andrew Tate for alpha advice and masculinity*
#
# Andrew Tate:
# "Best I can do is shit posting and comedy"
# @Cobratate Andrew became a shitposter after jail.
#
# &gt; I don't have an opinion. I have 47 criminal charges against me!
# @hunterhurleywx @WhiteHouse https://t.co/uhh9aZIM3C
# @ali_debow The real business model of college

# %%
len(tweets)
# Out:
# 40

# %%
# View as DataFrame
df_tweets = pd.json_normalize(tweets)
df_tweets.head(2)
# Out:
#     type                   id  \
# 0  tweet  1965155350392570283
# 1  tweet  1964882628810834046
#
#                                                  url  \
# 0  https://x.com/nelvOfficial/status/196515535039...
# 1  https://x.com/nelvOfficial/status/196488262881...
#
#                                           twitterUrl  \
# 0  https://twitter.com/nelvOfficial/status/196515...
# 1  https://twitter.com/nelvOfficial/status/196488...
#
#                                                 text              source  \
# 0  @martianwyrdlord Every man learns this by 25 -...  Twitter for iPhone
# 1  @ElizabethHolmes Do you want to pivot your car...  Twitter for iPhone
#
#    retweetCount  replyCount  likeCount  quoteCount  viewCount  \
# 0             0           0         25           0        488
# 1             2           0         85           0       4680
#
#                         createdAt lang  bookmarkCount  isReply  \
# 0  Mon Sep 08 20:48:41 +0000 2025   en              1     True
# 1  Mon Sep 08 02:44:59 +0000 2025   en              0     True
#
#            inReplyToId       conversationId displayTextRange  \
# 0  1965123155116380494  1965123155116380494        [17, 139]
# 1  1964838363845845133  1964838363845845133         [17, 93]
#
#        inReplyToUserId inReplyToUsername  card quoted_tweet retweeted_tweet  \
# 0  1609651923363168258   martianwyrdlord   NaN         None            None
# 1                 None              None   NaN         None            None
#
#    isLimitedReply article author.type author.userName  \
# 0           False    None        user    nelvOfficial
# 1            True    None        user    nelvOfficial
#
#                    author.url                 author.twitterUrl  \
# 0  https://x.com/nelvOfficial  https://twitter.com/nelvOfficial
# 1  https://x.com/nelvOfficial  https://twitter.com/nelvOfficial
#
#              author.id author.name  author.isVerified  author.isBlueVerified  \
# 0  1849903860984446976   david len              False                   True
# 1  1849903860984446976   david len              False                   True
#
#   author.verifiedType                              author.profilePicture  \
# 0                None  https://pbs.twimg.com/profile_images/190551462...
# 1                None  https://pbs.twimg.com/profile_images/190551462...
#
#                                  author.coverPicture author.description  \
# 0  https://pbs.twimg.com/profile_banners/18499038...
# 1  https://pbs.twimg.com/profile_banners/18499038...
#
#   author.location  author.followers  author.following author.status  \
# 0    Kuala Lumpur               169               308
# 1    Kuala Lumpur               169               308
#
#    author.canDm  author.canMediaTag                author.createdAt  \
# 0          True                True  Fri Oct 25 20:00:38 +0000 2024
# 1          True                True  Fri Oct 25 20:00:38 +0000 2024
#
#   author.entities.description.urls  author.fastFollowersCount  \
# 0                               []                          0
# 1                               []                          0
#
#    author.favouritesCount  author.hasCustomTimelines  author.isTranslator  \
# 0                    8813                       True                False
# 1                    8813                       True                False
#
#    author.mediaCount  author.statusesCount author.withheldInCountries  \
# 0                104                  1806                         []
# 1                104                  1806                         []
#
#    author.possiblySensitive  author.pinnedTweetIds  \
# 0                     False  [1939273097066217662]
# 1                     False  [1939273097066217662]
#
#                       author.profile_bio.description  \
# 0  Software engineer. ex-quant.\n\nAll relevant l...
# 1  Software engineer. ex-quant.\n\nAll relevant l...
#
#                 author.profile_bio.entities.url.urls  author.isAutomated  \
# 0  [{'display_url': 'nelworks.com', 'expanded_url...               False
# 1  [{'display_url': 'nelworks.com', 'expanded_url...               False
#
#   author.automatedBy                             entities.user_mentions  \
# 0               None  [{'id_str': '1609651923363168258', 'indices': ...
# 1               None  [{'id_str': '1629336979', 'indices': [0, 16], ...
#
#   extendedEntities.media card.binding_values  \
# 0                    NaN                 NaN
# 1                    NaN                 NaN
#
#   card.card_platform.platform.audience.name  \
# 0                                       NaN
# 1                                       NaN
#
#   card.card_platform.platform.device.name  \
# 0                                     NaN
# 1                                     NaN
#
#   card.card_platform.platform.device.version card.name card.url  \
# 0                                        NaN       NaN      NaN
# 1                                        NaN       NaN      NaN
#
#   card.user_refs_results entities.urls
# 0                    NaN           NaN
# 1                    NaN           NaN

# %%
df_tiny = collapse_dataframe(df_tweets, fields=TRUNCATED_TWEET_FIELDS)

# %%
df_tiny.head(2)
# Out:
#     type                   id  \
# 0  tweet  1965155350392570283
# 1  tweet  1964882628810834046
#
#                                                  url  \
# 0  https://x.com/nelvOfficial/status/196515535039...
# 1  https://x.com/nelvOfficial/status/196488262881...
#
#                         createdAt lang  \
# 0  Mon Sep 08 20:48:41 +0000 2025   en
# 1  Mon Sep 08 02:44:59 +0000 2025   en
#
#                                                 text  retweetCount  \
# 0  @martianwyrdlord Every man learns this by 25 -...             0
# 1  @ElizabethHolmes Do you want to pivot your car...             2
#
#    replyCount  likeCount  quoteCount  viewCount  bookmarkCount  isReply  \
# 0           0         25           0        488              1     True
# 1           0         85           0       4680              0     True
#
#            inReplyToId inReplyToUsername author.userName  \
# 0  1965123155116380494   martianwyrdlord    nelvOfficial
# 1  1964838363845845133              None    nelvOfficial
#
#                    author.url            author.id  author.isBlueVerified  \
# 0  https://x.com/nelvOfficial  1849903860984446976                   True
# 1  https://x.com/nelvOfficial  1849903860984446976                   True
#
#    author.followers  author.following
# 0               169               308
# 1               169               308
