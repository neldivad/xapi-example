# %% [markdown]
# # Twitter Followings Example
#
# This notebook loads cached followings (JSON/CSV) if present, or queries the API and displays a DataFrame.

# %%
import os
import requests
from dotenv import load_dotenv, find_dotenv
import pandas as pd

pd.set_option('display.max_columns', None)

# Local module
from pathlib import Path
import sys
project_root = Path.cwd().parent  # assumes notebook is in xapi-ex1/notebooks
sys.path.append(str(project_root / 'src'))

# %%
from users import (
    get_followings, 
    load_followings_cache, 
    save_followings_cache,
    search_tweets_advanced,
    get_user_tweets
)
from schema.tweets import (
    collapse_dicts, 
    collapse_dataframe, 
    TRUNCATED_TWEET_FIELDS
)


# Load env
load_dotenv(find_dotenv())
API_KEY = os.getenv('twitter_apiio_key')
if not API_KEY:
    raise RuntimeError('twitter_apiio_key not set in environment')

# %%
print(API_KEY)
# Out:
# aa53e158693c4f619323b0c8428179e9

# %%
# Params
USERNAME = 'nelvOfficial'  # change as needed
LIMIT = 60  # multiples of 200 recommended
USE_CACHE_FIRST = True

# %%
# Try cache else fetch

cached = load_followings_cache(USERNAME) if USE_CACHE_FIRST else None
if cached is None:
    print('Cache miss: fetching from API...')
    data = get_followings(USERNAME, limit=LIMIT, api_key=API_KEY)
    _ = save_followings_cache(USERNAME, data)  # JSON only
else:
    print('Loaded from cache')
    data = cached

# Normalize to DataFrame
df = pd.json_normalize(data.get('followings', []))
print(f"Rows: {len(df)}")

df.head(2)
# Out:
# Cache miss: fetching from API...
# Rows: 60
#                     id                          name      screen_name  \
# 0           1629336979              Elizabeth Holmes  ElizabethHolmes
# 1           2347612712        Grant Stenger (hiring)     GrantStenger
# 2  1341022359063384064                         Andex     andex_vuhieu
# 3  1962678461178486788            Predictive History     Pred_History
# 4           1115395026                  Jiang Xueqin      xueqinjiang
# 5             68854969                       ceteris   ceterispar1bus
# 6  1694157540932587521                      hoe_math      ItIsHoeMath
# 7            259897904                    @redaction        redaction
# 8  1402700298926317570  Fiscal.ai (formerly FinChat)        fiscal_ai
# 9           1720046887                Ilya Sutskever          ilyasut
#
#           userName        location                      url  \
# 0  ElizabethHolmes       Bryan, TX                     None
# 1     GrantStenger          Solana  https://t.co/iXxNQpGsaJ
# 2     andex_vuhieu         Vietnam  https://t.co/gFu9mcZxcb
# 3     Pred_History        Beijing   https://t.co/qnZjZzbw9r
# 4      xueqinjiang  Beijing, China  https://t.co/AeBWLr5xVC
# 5   ceterispar1bus     france 2027                     None
# 6      ItIsHoeMath          adrift  https://t.co/GdXdYjvWoG
# 7        redaction                  https://t.co/tFRmTOiYpy
# 8        fiscal_ai                  https://t.co/EP866SMIcu
# 9          ilyasut                                     None
#
#                                          description email  protected  \
# 0  Building a better world for my two children.\n...  None      False
# 1  CEO @kinetic_xyz | prev @janestreetgroup @poly...  None      False
# 2  I'm just a music composer/producer and a hardc...  None      False
# 3  Official clips account of @xueqinjiang's "Pred...  None      False
# 4          I analyze the past to predict the future.  None      False
# 5                          head of research | delphi  None      False
# 6  ▶ History's manliest and most hilarious sex ge...  None      False
# 7                                                     None      False
# 8  The future of investment research is here.  Fu...  None      False
# 9                                           SSI @SSI  None      False
#
#    verified  followers_count  following_count  friends_count  \
# 0     False            46973               54             54
# 1     False             5716             5949           5949
# 2     False              738              668            668
# 3     False             1503               32             32
# 4     False            21323              338            338
# 5     False            41388             1658           1658
# 6     False           236974              160            160
# 7     False             7871              746            746
# 8     False            67271               57             57
# 9     False           518331                3              3
#
#    favourites_count  statuses_count  media_tweets_count  \
# 0              2607             692                  45
# 1             96264            1978                 161
# 2              3212            1125                 175
# 3                 7              30                  22
# 4               124            2079                 633
# 5             61951            8758                 771
# 6             34695           17864                1228
# 7             61517           13471                2752
# 8              3329            3920                3038
# 9              4300            1192                  27
#
#                        created_at  \
# 0  Mon Jul 29 02:51:00 +0000 2013
# 1  Mon Feb 17 00:00:01 +0000 2014
# 2  Mon Dec 21 14:07:14 +0000 2020
# 3  Tue Sep 02 00:46:32 +0000 2025
# 4  Wed Jan 23 22:11:38 +0000 2013
# 5  Wed Aug 26 00:47:19 +0000 2009
# 6  Wed Aug 23 01:20:27 +0000 2023
# 7  Wed Mar 02 20:35:58 +0000 2011
# 8  Wed Jun 09 18:53:16 +0000 2021
# 9  Sun Sep 01 19:32:15 +0000 2013
#
#                                   profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/16293369...
# 1  https://pbs.twimg.com/profile_banners/23476127...
# 2  https://pbs.twimg.com/profile_banners/13410223...
# 3  https://pbs.twimg.com/profile_banners/19626784...
# 4                                               None
# 5  https://pbs.twimg.com/profile_banners/68854969...
# 6  https://pbs.twimg.com/profile_banners/16941575...
# 7  https://pbs.twimg.com/profile_banners/25989790...
# 8  https://pbs.twimg.com/profile_banners/14027002...
# 9  https://pbs.twimg.com/profile_banners/17200468...
#
#                              profile_image_url_https  can_dm
# 0  https://pbs.twimg.com/profile_images/593983848...   False
# 1  https://pbs.twimg.com/profile_images/174063514...   False
# 2  https://pbs.twimg.com/profile_images/192486058...   False
# 3  https://pbs.twimg.com/profile_images/196267854...   False
# 4  https://pbs.twimg.com/profile_images/378800000...   False
# 5  https://pbs.twimg.com/profile_images/187441785...   False
# 6  https://pbs.twimg.com/profile_images/194489223...   False
# 7  https://pbs.twimg.com/profile_images/172789733...   False
# 8  https://pbs.twimg.com/profile_images/196407367...   False
# 9  https://pbs.twimg.com/profile_images/196111571...   False

# %%
data
# Out:
# {'followings': [{'id': '1629336979',
#    'name': 'Elizabeth Holmes',
#    'screen_name': 'ElizabethHolmes',
#    'userName': 'ElizabethHolmes',
#    'location': 'Bryan, TX',
#    'url': None,
#    'description': 'Building a better world for my two children.\nInventor.\nFormer Theranos Founder and CEO\n\nMostly my words, posted by others',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 46973,
#    'following_count': 54,
#    'friends_count': 54,
#    'favourites_count': 2607,
#    'statuses_count': 692,
#    'media_tweets_count': 45,
#    'created_at': 'Mon Jul 29 02:51:00 +0000 2013',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1629336979/1756237939',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/593983848947396608/UKMbI7OO_normal.jpg',
#    'can_dm': False},
#   {'id': '2347612712',
#    'name': 'Grant Stenger (hiring)',
#    'screen_name': 'GrantStenger',
#    'userName': 'GrantStenger',
#    'location': 'Solana',
#    'url': 'https://t.co/iXxNQpGsaJ',
#    'description': 'CEO @kinetic_xyz | prev @janestreetgroup @polychain @numerai',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 5716,
#    'following_count': 5949,
#    'friends_count': 5949,
#    'favourites_count': 96264,
#    'statuses_count': 1978,
#    'media_tweets_count': 161,
#    'created_at': 'Mon Feb 17 00:00:01 +0000 2014',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2347612712/1749081802',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1740635145911279616/AVV7Y4eE_normal.jpg',
#    'can_dm': False},
#   {'id': '1341022359063384064',
#    'name': 'Andex',
#    'screen_name': 'andex_vuhieu',
#    'userName': 'andex_vuhieu',
#    'location': 'Vietnam',
#    'url': 'https://t.co/gFu9mcZxcb',
#    'description': "I'm just a music composer/producer and a hardcore gamer, I love arts and music a lot (✿◡‿◡)\nFeel free to DM me for original/BGM commissions ( •̀ ω •́ )✧",
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 738,
#    'following_count': 668,
#    'friends_count': 668,
#    'favourites_count': 3212,
#    'statuses_count': 1125,
#    'media_tweets_count': 175,
#    'created_at': 'Mon Dec 21 14:07:14 +0000 2020',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1341022359063384064/1754703205',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1924860584379789312/5jYkf9kB_normal.jpg',
#    'can_dm': False},
#   {'id': '1962678461178486788',
#    'name': 'Predictive History',
#    'screen_name': 'Pred_History',
#    'userName': 'Pred_History',
#    'location': 'Beijing ',
#    'url': 'https://t.co/qnZjZzbw9r',
#    'description': 'Official clips account of @xueqinjiang\'s "Predictive History" \n\nAnalyzing history to connect the past, explain the present, and predict the future.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 1503,
#    'following_count': 32,
#    'friends_count': 32,
#    'favourites_count': 7,
#    'statuses_count': 30,
#    'media_tweets_count': 22,
#    'created_at': 'Tue Sep 02 00:46:32 +0000 2025',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1962678461178486788/1756774245',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1962678541629411328/bZy8B1Po_normal.jpg',
#    'can_dm': False},
#   {'id': '1115395026',
#    'name': 'Jiang Xueqin',
#    'screen_name': 'xueqinjiang',
#    'userName': 'xueqinjiang',
#    'location': 'Beijing, China',
#    'url': 'https://t.co/AeBWLr5xVC',
#    'description': 'I analyze the past to predict the future.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 21323,
#    'following_count': 338,
#    'friends_count': 338,
#    'favourites_count': 124,
#    'statuses_count': 2079,
#    'media_tweets_count': 633,
#    'created_at': 'Wed Jan 23 22:11:38 +0000 2013',
#    'profile_banner_url': None,
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000848451509/5f1b16a512993ca62d200c267bee4d3b_normal.jpeg',
#    'can_dm': False},
#   {'id': '68854969',
#    'name': 'ceteris',
#    'screen_name': 'ceterispar1bus',
#    'userName': 'ceterispar1bus',
#    'location': 'france 2027',
#    'url': None,
#    'description': 'head of research | delphi',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 41388,
#    'following_count': 1658,
#    'friends_count': 1658,
#    'favourites_count': 61951,
#    'statuses_count': 8758,
#    'media_tweets_count': 771,
#    'created_at': 'Wed Aug 26 00:47:19 +0000 2009',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/68854969/1656511098',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1874417852997910528/DC0MnlJR_normal.jpg',
#    'can_dm': False},
#   {'id': '1694157540932587521',
#    'name': 'hoe_math',
#    'screen_name': 'ItIsHoeMath',
#    'userName': 'ItIsHoeMath',
#    'location': 'adrift',
#    'url': 'https://t.co/GdXdYjvWoG',
#    'description': "▶ History's manliest and most hilarious sex genius ◀\n⬇️CLICK⬇️THE⬇️LINK⬇️",
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 236974,
#    'following_count': 160,
#    'friends_count': 160,
#    'favourites_count': 34695,
#    'statuses_count': 17864,
#    'media_tweets_count': 1228,
#    'created_at': 'Wed Aug 23 01:20:27 +0000 2023',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1694157540932587521/1753506851',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1944892238385045510/i2c1Lfxj_normal.jpg',
#    'can_dm': False},
#   {'id': '259897904',
#    'name': '@redaction',
#    'screen_name': 'redaction',
#    'userName': 'redaction',
#    'location': '',
#    'url': 'https://t.co/tFRmTOiYpy',
#    'description': '',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 7871,
#    'following_count': 746,
#    'friends_count': 746,
#    'favourites_count': 61517,
#    'statuses_count': 13471,
#    'media_tweets_count': 2752,
#    'created_at': 'Wed Mar 02 20:35:58 +0000 2011',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/259897904/1700797998',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1727897334556618752/YoDeSuES_normal.jpg',
#    'can_dm': False},
#   {'id': '1402700298926317570',
#    'name': 'Fiscal.ai (formerly FinChat)',
#    'screen_name': 'fiscal_ai',
#    'userName': 'fiscal_ai',
#    'location': '',
#    'url': 'https://t.co/EP866SMIcu',
#    'description': 'The future of investment research is here.  Fundamental research platform for global equities, powered by AI.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 67271,
#    'following_count': 57,
#    'friends_count': 57,
#    'favourites_count': 3329,
#    'statuses_count': 3920,
#    'media_tweets_count': 3038,
#    'created_at': 'Wed Jun 09 18:53:16 +0000 2021',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1402700298926317570/1757106631',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1964073679006167040/08ynJM-D_normal.jpg',
#    'can_dm': False},
#   {'id': '1720046887',
#    'name': 'Ilya Sutskever',
#    'screen_name': 'ilyasut',
#    'userName': 'ilyasut',
#    'location': '',
#    'url': None,
#    'description': 'SSI @SSI',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 518331,
#    'following_count': 3,
#    'friends_count': 3,
#    'favourites_count': 4300,
#    'statuses_count': 1192,
#    'media_tweets_count': 27,
#    'created_at': 'Sun Sep 01 19:32:15 +0000 2013',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1720046887/1648404188',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1961115716889030656/We74zmE-_normal.jpg',
#    'can_dm': False},
#   {'id': '34799361',
#    'name': 'Dane Knecht 🦭',
#    'screen_name': 'dok2001',
#    'userName': 'dok2001',
#    'location': 'Austin, TX',
#    'url': 'https://t.co/sDFdHkSsjO',
#    'description': 'I help invent the future.  CTO @cloudflare.  Angel investor.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 20711,
#    'following_count': 1762,
#    'friends_count': 1762,
#    'favourites_count': 8733,
#    'statuses_count': 4062,
#    'media_tweets_count': 76,
#    'created_at': 'Fri Apr 24 01:26:07 +0000 2009',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/34799361/1712459281',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1933364396434001920/nNinLkYf_normal.jpg',
#    'can_dm': False},
#   {'id': '15540222',
#    'name': 'Guillermo Rauch',
#    'screen_name': 'rauchg',
#    'userName': 'rauchg',
#    'location': 'San Francisco, CA',
#    'url': 'https://t.co/qGYOw0ORB8',
#    'description': '@vercel CEO',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 296251,
#    'following_count': 469,
#    'friends_count': 469,
#    'favourites_count': 62841,
#    'statuses_count': 48383,
#    'media_tweets_count': 4465,
#    'created_at': 'Tue Jul 22 22:54:37 +0000 2008',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15540222/1696962299',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1783856060249595904/8TfcCN0r_normal.jpg',
#    'can_dm': False},
#   {'id': '1683049296',
#    'name': 'ᴙiiꙅɥn ✧',
#    'screen_name': 'Eriisshu',
#    'userName': 'Eriisshu',
#    'location': '',
#    'url': 'https://t.co/aBf6T6Q2wg',
#    'description': '🐰💙 Commission Artist | Commissions: https://t.co/vKd0UW5S2s |',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 3236,
#    'following_count': 314,
#    'friends_count': 314,
#    'favourites_count': 3460,
#    'statuses_count': 10078,
#    'media_tweets_count': 182,
#    'created_at': 'Mon Aug 19 11:56:29 +0000 2013',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1683049296/1746454764',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1899796415909613568/rhLuQlpu_normal.jpg',
#    'can_dm': False},
#   {'id': '1374864718591098886',
#    'name': 'SELO',
#    'screen_name': 'seloesque',
#    'userName': 'seloesque',
#    'location': '',
#    'url': 'https://t.co/YMs9LxwQrO',
#    'description': 'building palantir for oomfs at x-graphs dot com',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 3970,
#    'following_count': 598,
#    'friends_count': 598,
#    'favourites_count': 64183,
#    'statuses_count': 5352,
#    'media_tweets_count': 640,
#    'created_at': 'Wed Mar 24 23:24:37 +0000 2021',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1374864718591098886/1750104814',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1823846842569756672/K565UbM1_normal.jpg',
#    'can_dm': False},
#   {'id': '1915611068929630211',
#    'name': 'JoshSato',
#    'screen_name': 'josh_sato124',
#    'userName': 'josh_sato124',
#    'location': 'Austin, TX',
#    'url': None,
#    'description': 'Deep research for businesses.\nAI/ML background\nco-founder at https://t.co/UVtCnhPVME',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 297,
#    'following_count': 407,
#    'friends_count': 407,
#    'favourites_count': 884,
#    'statuses_count': 1117,
#    'media_tweets_count': 1,
#    'created_at': 'Fri Apr 25 03:37:37 +0000 2025',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1915611068929630211/1750649533',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1936989922763681792/314wKsDe_normal.jpg',
#    'can_dm': False},
#   {'id': '1221869640516874241',
#    'name': 'YIMBYLAND',
#    'screen_name': 'YIMBYLAND',
#    'userName': 'YIMBYLAND',
#    'location': 'YIMBYLAND',
#    'url': None,
#    'description': 'Reurbanizing America Through Abundance 🇺🇸',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 55555,
#    'following_count': 1995,
#    'friends_count': 1995,
#    'favourites_count': 106795,
#    'statuses_count': 22487,
#    'media_tweets_count': 4556,
#    'created_at': 'Mon Jan 27 18:58:28 +0000 2020',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1221869640516874241/1701853404',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1942121875007832064/7gUyp5rA_normal.jpg',
#    'can_dm': False},
#   {'id': '381289719',
#    'name': 'Nassim Nicholas Taleb',
#    'screen_name': 'nntaleb',
#    'userName': 'nntaleb',
#    'location': '',
#    'url': 'https://t.co/Y4YQnWaqyR',
#    'description': 'Flaneur: probability (philosophy), probability (mathematics), probability (real life),Phoenician wine, deadlifts & dead languages. Greco-Levantine.Canaan. #RWRI',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 1106131,
#    'following_count': 1607,
#    'friends_count': 1607,
#    'favourites_count': 90651,
#    'statuses_count': 50005,
#    'media_tweets_count': 6264,
#    'created_at': 'Wed Sep 28 02:19:07 +0000 2011',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/381289719/1402489958',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1835982938879508480/q4-Esddn_normal.jpg',
#    'can_dm': False},
#   {'id': '1799576387432353792',
#    'name': 'KANEI 🪶🎶',
#    'screen_name': 'AKA_Kanei',
#    'userName': 'AKA_Kanei',
#    'location': '',
#    'url': 'https://t.co/GOuDfimgCF',
#    'description': '🎤 Vtuber & Vsinger |🎶Singing for you everyday at 10am EST |🎮 Games & Music | OC:@nemikyu | pfp: @toszuca | Chibi Model: @0x4682B4',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 308,
#    'following_count': 416,
#    'friends_count': 416,
#    'favourites_count': 4203,
#    'statuses_count': 1508,
#    'media_tweets_count': 334,
#    'created_at': 'Sat Jun 08 22:57:23 +0000 2024',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1799576387432353792/1724792066',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1869782875488354305/Wjh6s7lc_normal.jpg',
#    'can_dm': False},
#   {'id': '4939401',
#    'name': 'Patrick Collison',
#    'screen_name': 'patrickc',
#    'userName': 'patrickc',
#    'location': 'patrick@stripe.com',
#    'url': 'https://t.co/LYgsEzNCdP',
#    'description': '@Stripe CEO, @ArcInstitute cofounder.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 557270,
#    'following_count': 30,
#    'friends_count': 30,
#    'favourites_count': 26404,
#    'statuses_count': 9840,
#    'media_tweets_count': 892,
#    'created_at': 'Tue Apr 17 01:46:27 +0000 2007',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4939401/1717860035',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/825622525342199809/_iAaSUQf_normal.jpg',
#    'can_dm': False},
#   {'id': '1435266698701991936',
#    'name': 'Isaiah Taylor - making nuclear reactors',
#    'screen_name': 'isaiah_p_taylor',
#    'userName': 'isaiah_p_taylor',
#    'location': 'LA',
#    'url': 'https://t.co/eW8Mg1uBxJ',
#    'description': 'Founder @valaratomics. Making nuclear reactors built for planetary scale.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 37041,
#    'following_count': 912,
#    'friends_count': 912,
#    'favourites_count': 61812,
#    'statuses_count': 10705,
#    'media_tweets_count': 1144,
#    'created_at': 'Tue Sep 07 15:40:31 +0000 2021',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1435266698701991936/1745517548',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1919954147853701120/PbALuNsl_normal.jpg',
#    'can_dm': False},
#   {'id': '1957244277337276416',
#    'name': 'inhuman resources',
#    'screen_name': 'inhumandept_vp',
#    'userName': 'inhumandept_vp',
#    'location': '',
#    'url': None,
#    'description': 'Tips from the darkside of HR. VP of HR for 10+ years. Employees are chesspieces, I am a grandmaster. I also like hot dogs.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 3052,
#    'following_count': 2,
#    'friends_count': 2,
#    'favourites_count': 106,
#    'statuses_count': 43,
#    'media_tweets_count': 12,
#    'created_at': 'Mon Aug 18 00:53:22 +0000 2025',
#    'profile_banner_url': None,
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1957244599698677760/YH1Z-Vb__normal.jpg',
#    'can_dm': False},
#   {'id': '1916301557643034624',
#    'name': 'Neet',
#    'screen_name': 'neet_sol',
#    'userName': 'neet_sol',
#    'location': '',
#    'url': 'https://t.co/A1uQvvykir',
#    'description': 'Not in Employment, Education, or Training',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 17658,
#    'following_count': 34,
#    'friends_count': 34,
#    'favourites_count': 7270,
#    'statuses_count': 4370,
#    'media_tweets_count': 1498,
#    'created_at': 'Sun Apr 27 01:21:16 +0000 2025',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1916301557643034624/1745716962',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1917570611427123200/EV0AWZ4g_normal.jpg',
#    'can_dm': False},
#   {'id': '1769144319733030912',
#    'name': 'oxbquant',
#    'screen_name': 'oxbquant',
#    'userName': 'oxbquant',
#    'location': 'London/NYC',
#    'url': None,
#    'description': 'resident trader metaphysicist. not financial advice.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 6728,
#    'following_count': 156,
#    'friends_count': 156,
#    'favourites_count': 17474,
#    'statuses_count': 2486,
#    'media_tweets_count': 134,
#    'created_at': 'Sat Mar 16 23:30:59 +0000 2024',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1769144319733030912/1757268368',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1960102181643661313/pP2MiIT4_normal.jpg',
#    'can_dm': False},
#   {'id': '1715687937206001664',
#    'name': 'abel 亚伯',
#    'screen_name': 'Abel_summation',
#    'userName': 'Abel_summation',
#    'location': '',
#    'url': None,
#    'description': 'high schooler researching parallel multi-agent systems @browser_use / AI forecasting research at https://t.co/3Ib0I8CjSB',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 1646,
#    'following_count': 323,
#    'friends_count': 323,
#    'favourites_count': 20747,
#    'statuses_count': 1150,
#    'media_tweets_count': 202,
#    'created_at': 'Sat Oct 21 11:14:29 +0000 2023',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1715687937206001664/1750533987',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1936505966167474176/tQzFYg_i_normal.jpg',
#    'can_dm': False},
#   {'id': '383951897',
#    'name': 'Yifan',
#    'screen_name': 'YifanBTH',
#    'userName': 'YifanBTH',
#    'location': 'London',
#    'url': 'https://t.co/A5xvB5K5lt',
#    'description': 'tech founder cooking in AI - \ndev deep dives: https://t.co/lw7GowLxsS - \nex: founding team @improbableio - \n@cambridgeuni compsci',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 1863,
#    'following_count': 368,
#    'friends_count': 368,
#    'favourites_count': 1040,
#    'statuses_count': 496,
#    'media_tweets_count': 74,
#    'created_at': 'Sun Oct 02 20:11:10 +0000 2011',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/383951897/1728999025',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1837905661973217280/qcD95b3L_normal.jpg',
#    'can_dm': False},
#   {'id': '1481624700946026497',
#    'name': 'coyuz',
#    'screen_name': 'coyuz0329',
#    'userName': 'coyuz0329',
#    'location': '',
#    'url': 'https://t.co/FMy4J0IvK2',
#    'description': '🇰🇷 🖌 🎮 🎧 치지직에서 방송합니다 그림 신청도 받습니다~ @coyuz0329_sub',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 1985,
#    'following_count': 112,
#    'friends_count': 112,
#    'favourites_count': 752,
#    'statuses_count': 296,
#    'media_tweets_count': 241,
#    'created_at': 'Thu Jan 13 13:50:39 +0000 2022',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1481624700946026497/1749485634',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1929178926968131584/1mEariEK_normal.jpg',
#    'can_dm': False},
#   {'id': '886358633646350340',
#    'name': 'LindyMan',
#    'screen_name': 'PaulSkallas',
#    'userName': 'PaulSkallas',
#    'location': 'WFH',
#    'url': None,
#    'description': 'Lindy Newsletter: https://t.co/k3A03LYLi1\n\n@lindyeffect',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 144528,
#    'following_count': 974,
#    'friends_count': 974,
#    'favourites_count': 88440,
#    'statuses_count': 68567,
#    'media_tweets_count': 9719,
#    'created_at': 'Sat Jul 15 22:55:40 +0000 2017',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/886358633646350340/1671223936',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1475164543504601088/ZmIsTj1r_normal.jpg',
#    'can_dm': False},
#   {'id': '3140391',
#    'name': 'Jason Crawford',
#    'screen_name': 'jasoncrawford',
#    'userName': 'jasoncrawford',
#    'location': 'Boston',
#    'url': 'https://t.co/3XSyMPr4Ku',
#    'description': 'Founder, @rootsofprogress. Working to build the progress community and movement. On book-writing sabbatical, trying not to check Twitter including DMs',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 39793,
#    'following_count': 3223,
#    'friends_count': 3223,
#    'favourites_count': 98081,
#    'statuses_count': 33684,
#    'media_tweets_count': 2445,
#    'created_at': 'Sun Apr 01 17:42:00 +0000 2007',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3140391/1719266188',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1227771761078362113/AaFoJ0VI_normal.jpg',
#    'can_dm': False},
#   {'id': '758272297425858560',
#    'name': 'Tequila Funk',
#    'screen_name': 'tequilafunks',
#    'userName': 'tequilafunks',
#    'location': 'Alicante, Spain',
#    'url': 'https://t.co/5YJqs2eztR',
#    'description': 'Music visuals @bangershowapp, Product Engineer at @remotion. Dubstep: https://t.co/pUsmOnuisS',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 373,
#    'following_count': 398,
#    'friends_count': 398,
#    'favourites_count': 4523,
#    'statuses_count': 2043,
#    'media_tweets_count': 452,
#    'created_at': 'Wed Jul 27 12:06:18 +0000 2016',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/758272297425858560/1723808409',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1767322612718346240/4gJhZxQE_normal.jpg',
#    'can_dm': False},
#   {'id': '451425069',
#    'name': '海拉鲁编程客',
#    'screen_name': 'hylarucoder',
#    'userName': 'hylarucoder',
#    'location': 'site👉',
#    'url': 'https://t.co/lB6diszeeC',
#    'description': '🖥️ Indie Maker\n🛠️ AI 能力边缘疯狂试探者\n📌 油管「海拉鲁编程客」\n 🌸 沦为程序员的段子手/猫咪',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 17725,
#    'following_count': 999,
#    'friends_count': 999,
#    'favourites_count': 3470,
#    'statuses_count': 13243,
#    'media_tweets_count': 1631,
#    'created_at': 'Sat Dec 31 12:37:37 +0000 2011',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/451425069/1581146904',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1725593465/1e73398765998062c75cc3f6____normal.jpg',
#    'can_dm': False},
#   {'id': '1913062361688100864',
#    'name': 'VYBE',
#    'screen_name': 'vybe_ai',
#    'userName': 'vybe_ai',
#    'location': '',
#    'url': 'https://t.co/1bbgrY1JRk',
#    'description': '',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 805,
#    'following_count': 2,
#    'friends_count': 2,
#    'favourites_count': 12,
#    'statuses_count': 0,
#    'media_tweets_count': 0,
#    'created_at': 'Fri Apr 18 02:49:55 +0000 2025',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1913062361688100864/1752986903',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1913062788328558592/9cNodOIQ_normal.jpg',
#    'can_dm': False},
#   {'id': '1940555919441440768',
#    'name': 'Kimu',
#    'screen_name': 'trykimu',
#    'userName': 'trykimu',
#    'location': '',
#    'url': 'https://t.co/Sy5jMcQn16',
#    'description': 'the best web video editor. join discord https://t.co/jBsqm3pB6Y',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 54,
#    'following_count': 9,
#    'friends_count': 9,
#    'favourites_count': 58,
#    'statuses_count': 27,
#    'media_tweets_count': 6,
#    'created_at': 'Wed Jul 02 23:39:42 +0000 2025',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1940555919441440768/1753067919',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1947136618722435072/34hjrjgY_normal.jpg',
#    'can_dm': False},
#   {'id': '1526902556491800576',
#    'name': 'John Yeo',
#    'screen_name': 'johnyeo_',
#    'userName': 'johnyeo_',
#    'location': 'London, San Francisco',
#    'url': 'https://t.co/LSi1nbGMzA',
#    'description': 'Stripe for AI startups @autumnpricing',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 3135,
#    'following_count': 888,
#    'friends_count': 888,
#    'favourites_count': 3951,
#    'statuses_count': 2278,
#    'media_tweets_count': 284,
#    'created_at': 'Wed May 18 12:28:48 +0000 2022',
#    'profile_banner_url': None,
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1935046528114016256/ZDKw5J0F_normal.jpg',
#    'can_dm': False},
#   {'id': '1422895361178447878',
#    'name': 'Remotion',
#    'screen_name': 'Remotion',
#    'userName': 'Remotion',
#    'location': 'npm init video',
#    'url': 'https://t.co/ubSbq7q8PS',
#    'description': 'Make videos programmatically.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 9393,
#    'following_count': 15,
#    'friends_count': 15,
#    'favourites_count': 783,
#    'statuses_count': 599,
#    'media_tweets_count': 187,
#    'created_at': 'Wed Aug 04 12:22:36 +0000 2021',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1422895361178447878/1688385350',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1570027602684919811/n_p-zzt7_normal.jpg',
#    'can_dm': False},
#   {'id': '51590414',
#    'name': 'Tom Brown',
#    'screen_name': 'nottombrown',
#    'userName': 'nottombrown',
#    'location': 'SF',
#    'url': None,
#    'description': 'Co-founder @AnthropicAI. Compute wrangler. Author of GPT-3. Cautiously optimistic.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 7475,
#    'following_count': 546,
#    'friends_count': 546,
#    'favourites_count': 3627,
#    'statuses_count': 652,
#    'media_tweets_count': 79,
#    'created_at': 'Sat Jun 27 23:31:04 +0000 2009',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/51590414/1391643340',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285266774267555840/LicLFbt3_normal.jpg',
#    'can_dm': False},
#   {'id': '34599151',
#    'name': 'Marcus Stenbeck',
#    'screen_name': 'marcusstenbeck',
#    'userName': 'marcusstenbeck',
#    'location': 'Stockholm',
#    'url': 'https://t.co/czYuj39IDe',
#    'description': 'builds animation technology • wip and dev tweets • https://t.co/qJXffUmgUb • https://t.co/YwkDIVVh03',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 571,
#    'following_count': 146,
#    'friends_count': 146,
#    'favourites_count': 1656,
#    'statuses_count': 3782,
#    'media_tweets_count': 409,
#    'created_at': 'Thu Apr 23 12:33:11 +0000 2009',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/34599151/1401302593',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/471717040181358592/XGTB058G_normal.jpeg',
#    'can_dm': False},
#   {'id': '1875078099538423808',
#    'name': 'MiniMax (official)',
#    'screen_name': 'MiniMax__AI',
#    'userName': 'MiniMax__AI',
#    'location': 'San Francisco',
#    'url': 'https://t.co/qwiwSLZj7I',
#    'description': 'Our mission is to build a world where intelligence thrives with everyone.\nMiniMax Agent: https://t.co/XzaTmAos0V',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 17760,
#    'following_count': 11,
#    'friends_count': 11,
#    'favourites_count': 322,
#    'statuses_count': 154,
#    'media_tweets_count': 62,
#    'created_at': 'Fri Jan 03 07:14:02 +0000 2025',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1875078099538423808/1735888954',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1875100548535574529/VxHk9HyU_normal.jpg',
#    'can_dm': False},
#   {'id': '954669073299734528',
#    'name': 'Harry McKenzie',
#    'screen_name': 'HARRY_1G',
#    'userName': 'HARRY_1G',
#    'location': 'Place, Japan',
#    'url': 'https://t.co/xm3p0WIkHy',
#    'description': 'systems engineer, ffmpeg enthusiast, open source maintainer, forklift certified (NEW!)',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 632,
#    'following_count': 220,
#    'friends_count': 220,
#    'favourites_count': 34403,
#    'statuses_count': 6896,
#    'media_tweets_count': 1192,
#    'created_at': 'Sat Jan 20 10:56:58 +0000 2018',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/954669073299734528/1551815542',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1855219657063497728/h_Bxytmp_normal.jpg',
#    'can_dm': False},
#   {'id': '1030310824831844352',
#    'name': 'Joseph',
#    'screen_name': 'JosephKChoi',
#    'userName': 'JosephKChoi',
#    'location': 'NYC',
#    'url': 'https://t.co/XsifxtD6iO',
#    'description': '📱 Private members club for viral consumer app founders @consumerclub_ 💼 Prev @Google @YouTube @UMich',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 13840,
#    'following_count': 902,
#    'friends_count': 902,
#    'favourites_count': 7759,
#    'statuses_count': 2361,
#    'media_tweets_count': 333,
#    'created_at': 'Fri Aug 17 04:30:17 +0000 2018',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1030310824831844352/1733177772',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1699323299594125312/WDkYVU48_normal.jpg',
#    'can_dm': False},
#   {'id': '1470159711295225863',
#    'name': 'Ryan McIntosh',
#    'screen_name': 'RyanMcIntosh33',
#    'userName': 'RyanMcIntosh33',
#    'location': 'Brooklyn, NY',
#    'url': 'https://t.co/juycEHYFO6',
#    'description': 'Building carbon-free rocket engines for power generation @Cedar__Labs founder, builder, decade+ in deep tech and hardware across energy, power gen and robotics',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 1295,
#    'following_count': 817,
#    'friends_count': 817,
#    'favourites_count': 6732,
#    'statuses_count': 4389,
#    'media_tweets_count': 423,
#    'created_at': 'Sun Dec 12 22:32:56 +0000 2021',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1470159711295225863/1743553405',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1851313401760305152/lY3h7iAB_normal.jpg',
#    'can_dm': False},
#   {'id': '1496779252905226243',
#    'name': 'Andrei Terteci',
#    'screen_name': 'andrei_terteci',
#    'userName': 'andrei_terteci',
#    'location': 'Create Marketing Visuals →',
#    'url': 'https://t.co/syu4OQIaSN',
#    'description': 'Indie maker building https://t.co/JQqWlxx4xX & https://t.co/Hoj9hv3VRg (new)',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 1931,
#    'following_count': 190,
#    'friends_count': 190,
#    'favourites_count': 11499,
#    'statuses_count': 8319,
#    'media_tweets_count': 636,
#    'created_at': 'Thu Feb 24 09:29:56 +0000 2022',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1496779252905226243/1721732840',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1846547195174002688/YFnN-ViW_normal.jpg',
#    'can_dm': False},
#   {'id': '11704332',
#    'name': 'weisser',
#    'screen_name': 'julianweisser',
#    'userName': 'julianweisser',
#    'location': 'San Francisco, CA',
#    'url': 'https://t.co/u3E2ljluIi',
#    'description': 'Founder/CEO building for those who are @solofounding. | Championing builders at @joinodf (find co-founders), @mergedotclub (microgrants), and @builderswhorun.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 24238,
#    'following_count': 4378,
#    'friends_count': 4378,
#    'favourites_count': 56514,
#    'statuses_count': 25733,
#    'media_tweets_count': 3586,
#    'created_at': 'Tue Jan 01 02:20:44 +0000 2008',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/11704332/1652376057',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1564297911050981377/2DXYydm9_normal.jpg',
#    'can_dm': False},
#   {'id': '1154702920945930240',
#    'name': 'Timo',
#    'screen_name': 'TimoCodes',
#    'userName': 'TimoCodes',
#    'location': 'Techno Optimism ',
#    'url': 'https://t.co/qMRZ7DFkx2',
#    'description': 'Government PM building AI tools for your career | 39 years coding + €5M projects | Building 7,000 money making prompts in 100 days https://t.co/jtvU8WDwzI',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 8222,
#    'following_count': 2584,
#    'friends_count': 2584,
#    'favourites_count': 47541,
#    'statuses_count': 36798,
#    'media_tweets_count': 5442,
#    'created_at': 'Fri Jul 26 10:40:04 +0000 2019',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1154702920945930240/1754813043',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1928631598435520513/OBCoUe2p_normal.jpg',
#    'can_dm': False},
#   {'id': '37723353',
#    'name': 'Derek Thompson',
#    'screen_name': 'DKThomp',
#    'userName': 'DKThomp',
#    'location': 'Washington, D.C.',
#    'url': 'https://t.co/GnWAlV1Hbi',
#    'description': 'Sign up for my new newsletter! (Link below) Also: Co-author of Abundance, host of Plain English, and contributing writer at The Atlantic.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 243091,
#    'following_count': 1992,
#    'friends_count': 1992,
#    'favourites_count': 38275,
#    'statuses_count': 20727,
#    'media_tweets_count': 2625,
#    'created_at': 'Mon May 04 18:41:21 +0000 2009',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/37723353/1613836014',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1605404261306679296/aq_L7W-z_normal.jpg',
#    'can_dm': False},
#   {'id': '14337099',
#    'name': 'Tobias Ahlin',
#    'screen_name': 'tobiasahlin',
#    'userName': 'tobiasahlin',
#    'location': 'Sweden',
#    'url': 'https://t.co/nkozDHnal2',
#    'description': 'Designing Copilot and Mona Sans @GitHub. Prev @Minecraft, @Spotify. he/him',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 11959,
#    'following_count': 1133,
#    'friends_count': 1133,
#    'favourites_count': 13883,
#    'statuses_count': 6034,
#    'media_tweets_count': 251,
#    'created_at': 'Tue Apr 08 23:13:56 +0000 2008',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14337099/1720866586',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1812071190002868224/LID6VMLI_normal.jpg',
#    'can_dm': False},
#   {'id': '860158302',
#    'name': 'Quanta Magazine',
#    'screen_name': 'QuantaMagazine',
#    'userName': 'QuantaMagazine',
#    'location': '',
#    'url': 'https://t.co/c7xRzWibUm',
#    'description': 'Illuminating math and science. Supported by @SimonsFdn. 2022 Pulitzer Prize in Explanatory Reporting.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 347545,
#    'following_count': 620,
#    'friends_count': 620,
#    'favourites_count': 2284,
#    'statuses_count': 34320,
#    'media_tweets_count': 14583,
#    'created_at': 'Wed Oct 03 18:44:34 +0000 2012',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/860158302/1747745761',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/859465000825614336/cBeerOAi_normal.jpg',
#    'can_dm': False},
#   {'id': '1884600164570304512',
#    'name': 'Autumn',
#    'screen_name': 'autumnpricing',
#    'userName': 'autumnpricing',
#    'location': 'SF',
#    'url': 'https://t.co/xsGQ0728Mg',
#    'description': 'your fave lil stripe wrapper',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 1873,
#    'following_count': 165,
#    'friends_count': 165,
#    'favourites_count': 3169,
#    'statuses_count': 1041,
#    'media_tweets_count': 82,
#    'created_at': 'Wed Jan 29 13:51:29 +0000 2025',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1884600164570304512/1755147677',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1885347060049707008/oqLg8_3R_normal.jpg',
#    'can_dm': False},
#   {'id': '876836424036659200',
#    'name': 'Anduril Industries',
#    'screen_name': 'anduriltech',
#    'userName': 'anduriltech',
#    'location': 'Orange County, CA ',
#    'url': 'https://t.co/69JMk4qfmE',
#    'description': 'Anduril is shaping the future of defense, transforming U.S. & allied military capabilities with advanced technology.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 154200,
#    'following_count': 281,
#    'friends_count': 281,
#    'favourites_count': 619,
#    'statuses_count': 1149,
#    'media_tweets_count': 415,
#    'created_at': 'Mon Jun 19 16:17:49 +0000 2017',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/876836424036659200/1744036319',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1892311837968125955/YmCsRx5t_normal.jpg',
#    'can_dm': False},
#   {'id': '28904071',
#    'name': 'Steven Simoni',
#    'screen_name': 'StevenSimoni',
#    'userName': 'StevenSimoni',
#    'location': 'Alexandria, VA',
#    'url': 'https://t.co/0QolSbgxyx',
#    'description': 'President @ Allen Control Systems. Founder and CEO of Bbot, acq by DoorDash.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 6104,
#    'following_count': 532,
#    'friends_count': 532,
#    'favourites_count': 3031,
#    'statuses_count': 1736,
#    'media_tweets_count': 319,
#    'created_at': 'Sun Apr 05 00:32:42 +0000 2009',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/28904071/1713325682',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/943577776388325376/5SDGE7_0_normal.jpg',
#    'can_dm': False},
#   {'id': '1917674440571195392',
#    'name': 'Arlan',
#    'screen_name': 'arlanrakh',
#    'userName': 'arlanrakh',
#    'location': 'sf',
#    'url': 'https://t.co/M4hwAHweqF',
#    'description': 'founder @nozomioai (YC S25) | hs junior dropout | forbes 30u30 | prev. stanford research at 16 | anime, cooking, running — e/acc',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 7865,
#    'following_count': 1388,
#    'friends_count': 1388,
#    'favourites_count': 3905,
#    'statuses_count': 2126,
#    'media_tweets_count': 346,
#    'created_at': 'Wed Apr 30 20:16:37 +0000 2025',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1917674440571195392/1746202006',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1921176578651791360/PkC1tNNu_normal.jpg',
#    'can_dm': False},
#   {'id': '2595244026',
#    'name': 'Eliezer Yudkowsky ⏹️',
#    'screen_name': 'ESYudkowsky',
#    'userName': 'ESYudkowsky',
#    'location': '',
#    'url': None,
#    'description': "The original AI alignment person.  Missing punctuation at the end of a sentence means it's humor.  If you're not sure, it's also very likely humor.",
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 206934,
#    'following_count': 101,
#    'friends_count': 101,
#    'favourites_count': 35400,
#    'statuses_count': 33535,
#    'media_tweets_count': 451,
#    'created_at': 'Sun Jun 29 20:14:32 +0000 2014',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2595244026/1527705951',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1934759522050166788/xKpgxWW5_normal.jpg',
#    'can_dm': False},
#   {'id': '1011666390741278725',
#    'name': 'Ben Landau-Taylor',
#    'screen_name': 'benlandautaylor',
#    'userName': 'benlandautaylor',
#    'location': 'San Francisco',
#    'url': 'https://t.co/gcipZ8j1I9',
#    'description': "Investigating power, society, and industry. Please don't get your ought all over my is.",
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 13110,
#    'following_count': 25,
#    'friends_count': 25,
#    'favourites_count': 16636,
#    'statuses_count': 5395,
#    'media_tweets_count': 516,
#    'created_at': 'Tue Jun 26 17:43:58 +0000 2018',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1011666390741278725/1550356290',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1280552411170471936/_t6hL5R__normal.jpg',
#    'can_dm': False},
#   {'id': '1447636957161422848',
#    'name': '德萊涅洛📜長期休養中【個人勢VTuber】',
#    'screen_name': 'DelaineNelo_',
#    'userName': 'DelaineNelo_',
#    'location': '維多利亞｜商業邀約、合作連動請洽詢YT信箱｜更多詳細→',
#    'url': 'https://t.co/5g6ljTAN52',
#    'description': '【身體魔法師｜@Noradobutsu_s】\n\n【御用小精靈｜@afa73995165】\n\n▶無断轉載禁止◀\n世界箱庭計劃部門唯一管理者\n叫涅洛就OK。\n日語⭕中文⭕英文🚫閩南語🉑',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 1804,
#    'following_count': 534,
#    'friends_count': 534,
#    'favourites_count': 6744,
#    'statuses_count': 11183,
#    'media_tweets_count': 2461,
#    'created_at': 'Mon Oct 11 18:55:35 +0000 2021',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1447636957161422848/1698325448',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1733789918525329408/V27-jwUW_normal.jpg',
#    'can_dm': False},
#   {'id': '1313201110258196481',
#    'name': 'Alex',
#    'screen_name': 'TickerSymbolYOU',
#    'userName': 'TickerSymbolYOU',
#    'location': 'Join 500K+ investors:',
#    'url': 'https://t.co/H6ywU5NpZF',
#    'description': 'I break down high-tech companies to help you invest in the best growth stocks | Former @MITLL rocket scientist turned full-time investor | $7M AUM (and growing)',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 48040,
#    'following_count': 389,
#    'friends_count': 389,
#    'favourites_count': 19238,
#    'statuses_count': 8983,
#    'media_tweets_count': 1302,
#    'created_at': 'Mon Oct 05 19:35:25 +0000 2020',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1313201110258196481/1688237058',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1754200836274622464/WDqxEQwl_normal.jpg',
#    'can_dm': False},
#   {'id': '18233920',
#    'name': 'Ryo Lu',
#    'screen_name': 'ryolu_',
#    'userName': 'ryolu_',
#    'location': 'San Francisco, CA',
#    'url': 'https://t.co/q1LbEDmZ1v',
#    'description': 'Head of Design @Cursor_ai. Early @NotionHQ, @Stripe, built startups. I make a world where anyone can make software. Aspiring k-pop idol.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 55121,
#    'following_count': 1536,
#    'friends_count': 1536,
#    'favourites_count': 29628,
#    'statuses_count': 17703,
#    'media_tweets_count': 1412,
#    'created_at': 'Fri Dec 19 03:39:15 +0000 2008',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18233920/1581710656',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1915014653295697921/KmMbglaO_normal.jpg',
#    'can_dm': False},
#   {'id': '14216123',
#    'name': 'Jim Cramer',
#    'screen_name': 'jimcramer',
#    'userName': 'jimcramer',
#    'location': 'New York City',
#    'url': 'https://t.co/GnLAn0PlX8',
#    'description': 'Host of @madmoneyoncnbc and I run the CNBC Investing Club. \nPreorder my new book now: https://t.co/uSkNnBTZSl',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 2298173,
#    'following_count': 692,
#    'friends_count': 692,
#    'favourites_count': 12046,
#    'statuses_count': 128682,
#    'media_tweets_count': 7817,
#    'created_at': 'Tue Mar 25 15:16:57 +0000 2008',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14216123/1754070399',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1461426655046606860/PzlSk4fZ_normal.jpg',
#    'can_dm': False},
#   {'id': '1295428909538906115',
#    'name': 'TTI',
#    'screen_name': 'TikTokInvestors',
#    'userName': 'TikTokInvestors',
#    'location': 'not financial advice ',
#    'url': None,
#    'description': 'We curate funny, interesting, and cringy finance / biz content. We are not affiliated with TikTok. Posts belong to respective owners.',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 292805,
#    'following_count': 1098,
#    'friends_count': 1098,
#    'favourites_count': 86970,
#    'statuses_count': 24764,
#    'media_tweets_count': 3542,
#    'created_at': 'Mon Aug 17 18:35:01 +0000 2020',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1295428909538906115/1618502746',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1689781362876940288/shUdFRd7_normal.jpg',
#    'can_dm': False},
#   {'id': '1192625531025608705',
#    'name': 'VCs Congratulating Themselves 👏👏👏',
#    'screen_name': 'VCBrags',
#    'userName': 'VCBrags',
#    'location': 'SF',
#    'url': 'https://t.co/l95DqVjyoI',
#    'description': "They're adding value™ And they're very proud of it. @BragsVentures",
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 273288,
#    'following_count': 4295,
#    'friends_count': 4295,
#    'favourites_count': 152988,
#    'statuses_count': 16899,
#    'media_tweets_count': 4725,
#    'created_at': 'Fri Nov 08 02:11:04 +0000 2019',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1192625531025608705/1573179650',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1342856329220812803/6K0HQ0h0_normal.png',
#    'can_dm': False},
#   {'id': '1039988371',
#    'name': 'Axel Kee 🐐🇲🇾',
#    'screen_name': 'soulchildpls',
#    'userName': 'soulchildpls',
#    'location': 'Kuala Lumpur',
#    'url': 'https://t.co/yb7OkasqJW',
#    'description': 'I like to make simple helpful apps. Learn how to customize your Shopify store without coding knowledge : https://t.co/vZI65P6puC',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 1875,
#    'following_count': 2636,
#    'friends_count': 2636,
#    'favourites_count': 38370,
#    'statuses_count': 16172,
#    'media_tweets_count': 1293,
#    'created_at': 'Thu Dec 27 16:18:10 +0000 2012',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1039988371/1620390664',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1685301063870713857/rb4nCGf-_normal.jpg',
#    'can_dm': False},
#   {'id': '945817135816654848',
#    'name': 'Trung Phan',
#    'screen_name': 'TrungTPhan',
#    'userName': 'TrungTPhan',
#    'location': 'My Saturday newsletter ➡️',
#    'url': 'https://t.co/QXcmEZDls6',
#    'description': 'Write on business with @workweekinc. Building a privacy-first AI research app (https://t.co/fZ5ObIy3Ra) and LLM API management platform (https://t.co/VTMMh1UFSj)',
#    'email': None,
#    'protected': False,
#    'verified': False,
#    'followers_count': 728966,
#    'following_count': 4216,
#    'friends_count': 4216,
#    'favourites_count': 191910,
#    'statuses_count': 79050,
#    'media_tweets_count': 14955,
#    'created_at': 'Wed Dec 27 00:42:32 +0000 2017',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/945817135816654848/1670800079',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1506362585448296448/LJg8kVSD_normal.jpg',
#    'can_dm': False}],
#  'has_next_page': True,
#  'next_cursor': '1839103907351694057',
#  'status': 'success',
#  'message': 'Fetched 60 followings for nelvOfficial'}

# %%
# # Save CSV separately under data/csvs
# from pathlib import Path
# csv_dir = (Path.cwd().parent / 'data' / 'csvs')
# csv_dir.mkdir(parents=True, exist_ok=True)
# csv_path = csv_dir / f"followings_{USERNAME.replace('@','')}.csv"
# df.to_csv(csv_path, index=False)
# print(f"Saved CSV to {csv_path}")

# %% [markdown]
# ## tweets

# %%
# search_tweets_advanced(
#     api_key=API_KEY,
#     query="from:nelvOfficial min_faves:30"
# )

# %%
# Params
USER_NAME = "nelvOfficial"   # or set USER_ID = "44196397"
USER_ID = 44196397
INCLUDE_REPLIES = True
LIMIT = 20                  # total tweets desired
start_date = "2025-09-01"
end_date = "2025-09-09"
min_faves = 30

# %%
resp = get_user_tweets(
    api_key=API_KEY,
    username=USER_NAME,
    limit=LIMIT,
    start_date=start_date,
    end_date=end_date,
    min_faves=min_faves,
    include_replies=INCLUDE_REPLIES,
)
tweets = resp["tweets"]

# %%
resp
# Out:
# {'tweets': [{'type': 'tweet',
#    'id': '1964882628810834046',
#    'url': 'https://x.com/nelvOfficial/status/1964882628810834046',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1964882628810834046',
#    'text': '@ElizabethHolmes Do you want to pivot your career to stand-up comedy? You are natural at this',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 2,
#    'replyCount': 0,
#    'likeCount': 33,
#    'quoteCount': 0,
#    'viewCount': 2165,
#    'createdAt': 'Mon Sep 08 02:44:59 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 0,
#    'isReply': True,
#    'inReplyToId': '1964838363845845133',
#    'conversationId': '1964838363845845133',
#    'displayTextRange': [17, 93],
#    'inReplyToUserId': None,
#    'inReplyToUsername': None,
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 307,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8633,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1795,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1629336979',
#       'indices': [0, 16],
#       'name': 'Elizabeth Holmes',
#       'screen_name': 'ElizabethHolmes'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': True,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1964695638169547042',
#    'url': 'https://x.com/nelvOfficial/status/1964695638169547042',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1964695638169547042',
#    'text': "@boneGPT Im more surprised by how could someone manage to convince the PM of one of the most nationalistic and xenophobic country to think such a policy proposal would be good for their career. \n\nThere's a lot of juice in this whole thing.",
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 2,
#    'likeCount': 109,
#    'quoteCount': 0,
#    'viewCount': 4821,
#    'createdAt': 'Sun Sep 07 14:21:57 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 1,
#    'isReply': True,
#    'inReplyToId': '1964583026207433024',
#    'conversationId': '1964583026207433024',
#    'displayTextRange': [9, 239],
#    'inReplyToUserId': '1644739974028316672',
#    'inReplyToUsername': 'boneGPT',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 307,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8633,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1795,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1644739974028316672',
#       'indices': [0, 8],
#       'name': 'bone',
#       'screen_name': 'boneGPT'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1963855148859498682',
#    'url': 'https://x.com/nelvOfficial/status/1963855148859498682',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1963855148859498682',
#    'text': '@nearcyan Grifting has no peak. \n\nBtw, the broccoli haircut grifter signal still continues to work',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 3,
#    'replyCount': 0,
#    'likeCount': 48,
#    'quoteCount': 0,
#    'viewCount': 5426,
#    'createdAt': 'Fri Sep 05 06:42:08 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 6,
#    'isReply': True,
#    'inReplyToId': '1963845078964715751',
#    'conversationId': '1963845078964715751',
#    'displayTextRange': [10, 98],
#    'inReplyToUserId': '1128159740599656448',
#    'inReplyToUsername': 'nearcyan',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 307,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8633,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1795,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1128159740599656448',
#       'indices': [0, 9],
#       'name': 'near',
#       'screen_name': 'nearcyan'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1963803997023957023',
#    'url': 'https://x.com/nelvOfficial/status/1963803997023957023',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1963803997023957023',
#    'text': '@signulll chatgpt inherited its sycophancy from his ceo.',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 1,
#    'likeCount': 37,
#    'quoteCount': 0,
#    'viewCount': 1473,
#    'createdAt': 'Fri Sep 05 03:18:53 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 0,
#    'isReply': True,
#    'inReplyToId': '1963802818118033552',
#    'conversationId': '1963802818118033552',
#    'displayTextRange': [10, 56],
#    'inReplyToUserId': '1717671858521194496',
#    'inReplyToUsername': 'signulll',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 307,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8633,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1795,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '1717671858521194496',
#       'indices': [0, 9],
#       'name': 'signüll',
#       'screen_name': 'signulll'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None},
#   {'type': 'tweet',
#    'id': '1963440133166043580',
#    'url': 'https://x.com/nelvOfficial/status/1963440133166043580',
#    'twitterUrl': 'https://twitter.com/nelvOfficial/status/1963440133166043580',
#    'text': '@julianweisser He is the same guy who wants 70% for having the idea and 30% for you who builds it',
#    'source': 'Twitter for iPhone',
#    'retweetCount': 0,
#    'replyCount': 0,
#    'likeCount': 31,
#    'quoteCount': 0,
#    'viewCount': 2072,
#    'createdAt': 'Thu Sep 04 03:13:01 +0000 2025',
#    'lang': 'en',
#    'bookmarkCount': 0,
#    'isReply': True,
#    'inReplyToId': '1963430112931545253',
#    'conversationId': '1963430112931545253',
#    'displayTextRange': [15, 97],
#    'inReplyToUserId': '11704332',
#    'inReplyToUsername': 'julianweisser',
#    'author': {'type': 'user',
#     'userName': 'nelvOfficial',
#     'url': 'https://x.com/nelvOfficial',
#     'twitterUrl': 'https://twitter.com/nelvOfficial',
#     'id': '1849903860984446976',
#     'name': 'david len',
#     'isVerified': False,
#     'isBlueVerified': True,
#     'verifiedType': None,
#     'profilePicture': 'https://pbs.twimg.com/profile_images/1905514620598861824/AnLDRr_7_normal.jpg',
#     'coverPicture': 'https://pbs.twimg.com/profile_banners/1849903860984446976/1752183683',
#     'description': '',
#     'location': 'Kuala Lumpur',
#     'followers': 169,
#     'following': 307,
#     'status': '',
#     'canDm': True,
#     'canMediaTag': True,
#     'createdAt': 'Fri Oct 25 20:00:38 +0000 2024',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fastFollowersCount': 0,
#     'favouritesCount': 8633,
#     'hasCustomTimelines': True,
#     'isTranslator': False,
#     'mediaCount': 104,
#     'statusesCount': 1795,
#     'withheldInCountries': [],
#     'affiliatesHighlightedLabel': {},
#     'possiblySensitive': False,
#     'pinnedTweetIds': ['1939273097066217662'],
#     'profile_bio': {'description': 'Software engineer. ex-quant.\n\nAll relevant links on the website.',
#      'entities': {'description': {},
#       'url': {'urls': [{'display_url': 'nelworks.com',
#          'expanded_url': 'http://www.nelworks.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/ejA6le2oHq'}]}}},
#     'isAutomated': False,
#     'automatedBy': None},
#    'extendedEntities': {},
#    'card': None,
#    'place': {},
#    'entities': {'user_mentions': [{'id_str': '11704332',
#       'indices': [0, 14],
#       'name': 'weisser',
#       'screen_name': 'julianweisser'}]},
#    'quoted_tweet': None,
#    'retweeted_tweet': None,
#    'isLimitedReply': False,
#    'article': None}],
#  'has_next_page': False,
#  'next_cursor': None,
#  'status': 'success',
#  'message': 'Fetched 5 tweets for query: from:nelvOfficial since:2025-09-01 until:2025-09-09 min_faves:30'}

# %%
len(tweets)
# Out:
# 5

# %%
# View as DataFrame
df = pd.json_normalize(tweets)
df.head(2)
# Out:
#     type                   id  \
# 0  tweet  1964882628810834046
# 1  tweet  1964695638169547042
#
#                                                  url  \
# 0  https://x.com/nelvOfficial/status/196488262881...
# 1  https://x.com/nelvOfficial/status/196469563816...
#
#                                           twitterUrl  \
# 0  https://twitter.com/nelvOfficial/status/196488...
# 1  https://twitter.com/nelvOfficial/status/196469...
#
#                                                 text              source  \
# 0  @ElizabethHolmes Do you want to pivot your car...  Twitter for iPhone
# 1  @boneGPT Im more surprised by how could someon...  Twitter for iPhone
#
#    retweetCount  replyCount  likeCount  quoteCount  viewCount  \
# 0             2           0         33           0       2165
# 1             0           2        109           0       4821
#
#                         createdAt lang  bookmarkCount  isReply  \
# 0  Mon Sep 08 02:44:59 +0000 2025   en              0     True
# 1  Sun Sep 07 14:21:57 +0000 2025   en              1     True
#
#            inReplyToId       conversationId displayTextRange  \
# 0  1964838363845845133  1964838363845845133         [17, 93]
# 1  1964583026207433024  1964583026207433024         [9, 239]
#
#        inReplyToUserId inReplyToUsername  card quoted_tweet retweeted_tweet  \
# 0                 None              None  None         None            None
# 1  1644739974028316672           boneGPT  None         None            None
#
#    isLimitedReply article author.type author.userName  \
# 0            True    None        user    nelvOfficial
# 1           False    None        user    nelvOfficial
#
#                    author.url                 author.twitterUrl  \
# 0  https://x.com/nelvOfficial  https://twitter.com/nelvOfficial
# 1  https://x.com/nelvOfficial  https://twitter.com/nelvOfficial
#
#              author.id author.name  author.isVerified  author.isBlueVerified  \
# 0  1849903860984446976   david len              False                   True
# 1  1849903860984446976   david len              False                   True
#
#   author.verifiedType                              author.profilePicture  \
# 0                None  https://pbs.twimg.com/profile_images/190551462...
# 1                None  https://pbs.twimg.com/profile_images/190551462...
#
#                                  author.coverPicture author.description  \
# 0  https://pbs.twimg.com/profile_banners/18499038...
# 1  https://pbs.twimg.com/profile_banners/18499038...
#
#   author.location  author.followers  author.following author.status  \
# 0    Kuala Lumpur               169               307
# 1    Kuala Lumpur               169               307
#
#    author.canDm  author.canMediaTag                author.createdAt  \
# 0          True                True  Fri Oct 25 20:00:38 +0000 2024
# 1          True                True  Fri Oct 25 20:00:38 +0000 2024
#
#   author.entities.description.urls  author.fastFollowersCount  \
# 0                               []                          0
# 1                               []                          0
#
#    author.favouritesCount  author.hasCustomTimelines  author.isTranslator  \
# 0                    8633                       True                False
# 1                    8633                       True                False
#
#    author.mediaCount  author.statusesCount author.withheldInCountries  \
# 0                104                  1795                         []
# 1                104                  1795                         []
#
#    author.possiblySensitive  author.pinnedTweetIds  \
# 0                     False  [1939273097066217662]
# 1                     False  [1939273097066217662]
#
#                       author.profile_bio.description  \
# 0  Software engineer. ex-quant.\n\nAll relevant l...
# 1  Software engineer. ex-quant.\n\nAll relevant l...
#
#                 author.profile_bio.entities.url.urls  author.isAutomated  \
# 0  [{'display_url': 'nelworks.com', 'expanded_url...               False
# 1  [{'display_url': 'nelworks.com', 'expanded_url...               False
#
#   author.automatedBy                             entities.user_mentions
# 0               None  [{'id_str': '1629336979', 'indices': [0, 16], ...
# 1               None  [{'id_str': '1644739974028316672', 'indices': ...

# %%
df_tiny = collapse_dataframe(df, fields=TRUNCATED_TWEET_FIELDS)

# %%
df_tiny.head(2)
# Out:
#     type                   id  \
# 0  tweet  1964882628810834046
# 1  tweet  1964695638169547042
#
#                                                  url  \
# 0  https://x.com/nelvOfficial/status/196488262881...
# 1  https://x.com/nelvOfficial/status/196469563816...
#
#                         createdAt lang  \
# 0  Mon Sep 08 02:44:59 +0000 2025   en
# 1  Sun Sep 07 14:21:57 +0000 2025   en
#
#                                                 text  retweetCount  \
# 0  @ElizabethHolmes Do you want to pivot your car...             2
# 1  @boneGPT Im more surprised by how could someon...             0
#
#    replyCount  likeCount  quoteCount  viewCount  bookmarkCount  isReply  \
# 0           0         33           0       2165              0     True
# 1           2        109           0       4821              1     True
#
#            inReplyToId inReplyToUsername author.userName  \
# 0  1964838363845845133              None    nelvOfficial
# 1  1964583026207433024           boneGPT    nelvOfficial
#
#                    author.url            author.id  author.isBlueVerified  \
# 0  https://x.com/nelvOfficial  1849903860984446976                   True
# 1  https://x.com/nelvOfficial  1849903860984446976                   True
#
#    author.followers  author.following
# 0               169               307
# 1               169               307
